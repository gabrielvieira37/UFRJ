# %%
from __future__ import division

# import matplotlib.pyplot as plt
from collections import Counter
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.svm import OneClassSVM
from sklearn.model_selection import GridSearchCV
# Out:
# /home/labamn/miniconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
df_train = pd.read_csv('new_train.csv')

# %%
print (Counter(df_train['TARGET']))
# Out:
# Counter({0: 57665, 1: 2355})

# %%
names = df_train.columns.values.tolist()[:-1]

# %%
df_test = pd.read_csv('test.csv', names=names)

# %%
# process base
def process_base(train, test):
    train.loc[(train['var38']>117310.979) & (train['var38']<117310.98), 'var38'] = -999.0
    test.loc[(test['var38']>117310.979) & (test['var38']<117310.98), 'var38'] = -999.0

    train.loc[train['var3']==-999999, 'var3'] = -999.0
    test.loc[test['var3']==-999999, 'var3'] = -999.0

    for f in ['imp_op_var40_comer_ult1', 'imp_op_var40_efect_ult3', 'imp_op_var41_comer_ult3', 'imp_sal_var16_ult1']:
        train.loc[train[f]==0.0, f] = -999.0
        test.loc[test[f]==0.0, f] = -999.0
        
    return train, test

# %%
df_train, df_test = process_base(df_train, df_test)

# %%
# remove constant columns
remove = []
for col in df_train.columns:
    if df_train[col].std() == 0:
        remove.append(col)

df_train.drop(remove, axis=1, inplace=True)
df_test.drop(remove, axis=1, inplace=True)

# %%
# remove duplicated columns
remove = []
c = df_train.columns
for i in range(len(c)-1):
    v = df_train[c[i]].values
    for j in range(i+1,len(c)):
        if np.array_equal(v,df_train[c[j]].values):
            remove.append(c[j])
df_train.drop(remove, axis=1, inplace=True)
df_test.drop(remove, axis=1, inplace=True)

# %%
# insert sum zeros feature
flist = [x for x in df_train.columns if not x in ['ID','TARGET']]
df_train.insert(1, 'SumZeros', (df_train[flist] == 0).astype(int).sum(axis=1))
df_test.insert(1, 'SumZeros', (df_test[flist] == 0).astype(int).sum(axis=1))

# %%
def normalize_features(train, test):
    flist = [x for x in train.columns if not x in ['ID','TARGET']]
    for f in flist:
        if train[f].max() == 9999999999.0:
            fmax = train.loc[train[f]<9999999999.0, f].max()
            train.loc[train[f]==9999999999.0, f] = fmax + 1

        if len(train.loc[train[f]<0, f].value_counts()) == 1:
            train.loc[train[f]<0, f] = -1.0
            test.loc[test[f]<0, f] = -1.0
            fmax = max(np.max(train[f]), np.max(test[f]))
            if fmax > 0:
                train.loc[train[f]>0, f] = 1.0*train.loc[train[f]>0, f]/fmax
                test.loc[test[f]>0, f] = 1.0*test.loc[test[f]>0, f]/fmax

        if len(train.loc[train[f]<0, f]) == 0:
            fmax = max(np.max(train[f]), np.max(test[f]))
            if fmax > 0:
                train.loc[train[f]>0, f] = 1.0*train.loc[train[f]>0, f]/fmax
                test.loc[test[f]>0, f] = 1.0*test.loc[test[f]>0, f]/fmax

        if len(train.loc[train[f]<0, f].value_counts()) > 1:
            fmax = max(np.max(train[f]), np.max(test[f]))
            if fmax > 0:
                train[f] = 1.0*train[f]/fmax
                test[f] = 1.0*test[f]/fmax

    return train, test

# %%
df_train, df_test = normalize_features(df_train, df_test)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
x_train_projected = pca.fit_transform(df_train.drop(['TARGET'], axis=1).values)
x_test_projected = pca.transform(df_test.values)
df_train.insert(1, 'PCAOne', x_train_projected[:, 0])
df_train.insert(1, 'PCATwo', x_train_projected[:, 1])
df_test.insert(1, 'PCAOne', x_test_projected[:, 0])
df_test.insert(1, 'PCATwo', x_test_projected[:, 1])

# %%
# from sklearn.manifold import TSNE
# from sklearn.decomposition import TruncatedSVD
# from sklearn.preprocessing import StandardScaler

# X = df_train.drop(['TARGET'], axis=1).append(df_test).values
# svd = TruncatedSVD(n_components=30)

# len_train = df_train.values.shape[0]

# X_svd = svd.fit_transform(X)
# X_scaled = StandardScaler().fit_transform(X_svd)
# modelTSNE = TSNE(n_components=2,random_state=0)
# feats_tsne = modelTSNE.fit_transform(X_scaled)
# feats_tsne_train = pd.DataFrame(feats_tsne[:len_train], columns=['tsne1', 'tsne2'])
# feats_tsne_test = pd.DataFrame(feats_tsne[len_train:], columns=['tsne1', 'tsne2'])
# # feats_tsne['ID'] = train[['ID']].append(test[['ID']], ignore_index=True)['ID'].values
# df_train = pd.merge(train, feats_tsne, on='ID', how='left')
# df_test = pd.merge(test, feats_tsne, on='ID', how='left')


# # tsne = TSNE(n_components=2)

# %%
y_train = df_train['TARGET'].values
X_train = df_train.drop(['TARGET'], axis=1).values

X_test = df_test.values

# length of dataset
len_train = len(X_train)
len_test  = len(X_test)

# %%
# classifier
clf = xgb.XGBClassifier(missing=-999.0, max_depth=5, min_child_weight=5,
                        n_estimators=500, learning_rate=0.02, gamma=1.0, 
                        nthread=-1, subsample=0.8, colsample_bytree=1.0, colsample_bylevel=0.7, seed=123089)

X_fit, X_eval, y_fit, y_eval= train_test_split(X_train, y_train, test_size=0.3)

# %%
# param_test1 = {
# #     'max_depth':range(1,10,1),
# #     'min_child_weight':[1,2],
#     'gamma':[0.0, 0.05, 0.25, 0.75],
# #     'subsample':[0.75, 0.95],
# #     'colsample_bytree':[0.75,0.95],
# #     'reg_alpha':[0, 0.01],
#     'learning_rate':[0.003, 0.01, 0.03, 0.1, 0.3]
# }

# %%
# gsearch1 = GridSearchCV(estimator=xgb.sklearn.XGBClassifier(missing=np.nan, max_depth=5,
#                         min_child_weight=1,objective= 'binary:logistic', gamma=0,
#                         scale_pos_weight=1, n_estimators=350, learning_rate=0.03, 
#                         nthread=-1, subsample=0.95, colsample_bytree=0.85, seed=4242), 
# param_grid = param_test1, scoring='roc_auc',iid=False, verbose=30, n_jobs=-1, cv=5)

# %%
# gsearch1.fit(X_train, y_train)
# # print 'cv_results', gsearch1.cv_results_
# print ('\n')
# print ('best parameters', gsearch1.best_params_ )
# print ('best_score', gsearch1.best_score_)

# %%
# fitting
clf.fit(X_train, y_train, early_stopping_rounds=20, eval_metric="auc", eval_set=[(X_eval, y_eval)])
# Out:
# [0]	validation_0-auc:0.807998
# Will train until validation_0-auc hasn't improved in 20 rounds.
# [1]	validation_0-auc:0.82185
# [2]	validation_0-auc:0.82322
# [3]	validation_0-auc:0.827017
# [4]	validation_0-auc:0.829212
# [5]	validation_0-auc:0.832035
# [6]	validation_0-auc:0.832015
# [7]	validation_0-auc:0.834061
# [8]	validation_0-auc:0.832787
# [9]	validation_0-auc:0.833811
# [10]	validation_0-auc:0.835116
# [11]	validation_0-auc:0.836065
# [12]	validation_0-auc:0.836788
# [13]	validation_0-auc:0.836137
# [14]	validation_0-auc:0.83633
# [15]	validation_0-auc:0.836607
# [16]	validation_0-auc:0.836936
# [17]	validation_0-auc:0.836495
# [18]	validation_0-auc:0.836795
# [19]	validation_0-auc:0.836624
# [20]	validation_0-auc:0.836751
# [21]	validation_0-auc:0.837105
# [22]	validation_0-auc:0.837652
# [23]	validation_0-auc:0.838193
# [24]	validation_0-auc:0.83851
# [25]	validation_0-auc:0.83916
# [26]	validation_0-auc:0.839583
# [27]	validation_0-auc:0.839763
# [28]	validation_0-auc:0.839763
# [29]	validation_0-auc:0.839692
# [30]	validation_0-auc:0.839662
# [31]	validation_0-auc:0.839739
# [32]	validation_0-auc:0.839878
# [33]	validation_0-auc:0.840194
# [34]	validation_0-auc:0.840285
# [35]	validation_0-auc:0.840097
# [36]	validation_0-auc:0.839958
# [37]	validation_0-auc:0.84036
# [38]	validation_0-auc:0.840845
# [39]	validation_0-auc:0.840913
# [40]	validation_0-auc:0.840854
# [41]	validation_0-auc:0.84099
# [42]	validation_0-auc:0.841923
# [43]	validation_0-auc:0.841665
# [44]	validation_0-auc:0.842041
# [45]	validation_0-auc:0.842138
# [46]	validation_0-auc:0.842461
# [47]	validation_0-auc:0.842724
# [48]	validation_0-auc:0.843006
# [49]	validation_0-auc:0.842963
# [50]	validation_0-auc:0.843171
# [51]	validation_0-auc:0.843449
# [52]	validation_0-auc:0.843547
# [53]	validation_0-auc:0.84372
# [54]	validation_0-auc:0.843771
# [55]	validation_0-auc:0.844118
# [56]	validation_0-auc:0.844228
# [57]	validation_0-auc:0.844251
# [58]	validation_0-auc:0.844322
# [59]	validation_0-auc:0.844473
# [60]	validation_0-auc:0.844667
# [61]	validation_0-auc:0.844693
# [62]	validation_0-auc:0.844714
# [63]	validation_0-auc:0.84474
# [64]	validation_0-auc:0.844876
# [65]	validation_0-auc:0.8447
# [66]	validation_0-auc:0.844642
# [67]	validation_0-auc:0.844594
# [68]	validation_0-auc:0.844692
# [69]	validation_0-auc:0.844767
# [70]	validation_0-auc:0.844679
# [71]	validation_0-auc:0.844672
# [72]	validation_0-auc:0.844831
# [73]	validation_0-auc:0.845004
# [74]	validation_0-auc:0.844916
# [75]	validation_0-auc:0.845109
# [76]	validation_0-auc:0.845081
# [77]	validation_0-auc:0.845111
# [78]	validation_0-auc:0.845339
# [79]	validation_0-auc:0.845288
# [80]	validation_0-auc:0.84575
# [81]	validation_0-auc:0.845665
# [82]	validation_0-auc:0.845976
# [83]	validation_0-auc:0.846041
# [84]	validation_0-auc:0.846109
# [85]	validation_0-auc:0.84604
# [86]	validation_0-auc:0.846106
# [87]	validation_0-auc:0.846053
# [88]	validation_0-auc:0.846009
# [89]	validation_0-auc:0.846022
# [90]	validation_0-auc:0.846788
# [91]	validation_0-auc:0.846835
# [92]	validation_0-auc:0.847055
# [93]	validation_0-auc:0.847185
# [94]	validation_0-auc:0.847112
# [95]	validation_0-auc:0.847195
# [96]	validation_0-auc:0.847293
# [97]	validation_0-auc:0.847393
# [98]	validation_0-auc:0.84738
# [99]	validation_0-auc:0.847462
# [100]	validation_0-auc:0.847605
# [101]	validation_0-auc:0.847911
# [102]	validation_0-auc:0.848028
# [103]	validation_0-auc:0.848344
# [104]	validation_0-auc:0.848428
# [105]	validation_0-auc:0.848517
# [106]	validation_0-auc:0.848666
# [107]	validation_0-auc:0.848705
# [108]	validation_0-auc:0.848863
# [109]	validation_0-auc:0.848818
# [110]	validation_0-auc:0.848848
# [111]	validation_0-auc:0.848969
# [112]	validation_0-auc:0.849087
# [113]	validation_0-auc:0.849196
# [114]	validation_0-auc:0.849157
# [115]	validation_0-auc:0.849241
# [116]	validation_0-auc:0.849488
# [117]	validation_0-auc:0.849549
# [118]	validation_0-auc:0.84957
# [119]	validation_0-auc:0.849515
# [120]	validation_0-auc:0.849606
# [121]	validation_0-auc:0.849694
# [122]	validation_0-auc:0.84969
# [123]	validation_0-auc:0.849883
# [124]	validation_0-auc:0.849922
# [125]	validation_0-auc:0.85002
# [126]	validation_0-auc:0.850134
# [127]	validation_0-auc:0.850375
# [128]	validation_0-auc:0.850441
# [129]	validation_0-auc:0.85068
# [130]	validation_0-auc:0.850854
# [131]	validation_0-auc:0.851039
# [132]	validation_0-auc:0.85109
# [133]	validation_0-auc:0.851039
# [134]	validation_0-auc:0.851222
# [135]	validation_0-auc:0.851246
# [136]	validation_0-auc:0.851281
# [137]	validation_0-auc:0.851261
# [138]	validation_0-auc:0.851358
# [139]	validation_0-auc:0.851385
# [140]	validation_0-auc:0.851512
# [141]	validation_0-auc:0.851858
# [142]	validation_0-auc:0.852013
# [143]	validation_0-auc:0.852128
# [144]	validation_0-auc:0.852329
# [145]	validation_0-auc:0.852622
# [146]	validation_0-auc:0.852622
# [147]	validation_0-auc:0.852623
# [148]	validation_0-auc:0.852737
# [149]	validation_0-auc:0.852932
# [150]	validation_0-auc:0.852985
# [151]	validation_0-auc:0.853086
# [152]	validation_0-auc:0.853337
# [153]	validation_0-auc:0.853361
# [154]	validation_0-auc:0.853589
# [155]	validation_0-auc:0.853679
# [156]	validation_0-auc:0.853779
# [157]	validation_0-auc:0.853791
# [158]	validation_0-auc:0.853942
# [159]	validation_0-auc:0.854212
# [160]	validation_0-auc:0.854387
# [161]	validation_0-auc:0.854433
# [162]	validation_0-auc:0.854638
# [163]	validation_0-auc:0.854792
# [164]	validation_0-auc:0.854974
# [165]	validation_0-auc:0.855007
# [166]	validation_0-auc:0.85493
# [167]	validation_0-auc:0.855041
# [168]	validation_0-auc:0.855237
# [169]	validation_0-auc:0.855305
# [170]	validation_0-auc:0.855351
# [171]	validation_0-auc:0.855334
# [172]	validation_0-auc:0.855422
# [173]	validation_0-auc:0.85556
# [174]	validation_0-auc:0.855631
# [175]	validation_0-auc:0.855669
# [176]	validation_0-auc:0.855769
# [177]	validation_0-auc:0.855922
# [178]	validation_0-auc:0.856064
# [179]	validation_0-auc:0.856162
# [180]	validation_0-auc:0.856286
# [181]	validation_0-auc:0.856461
# [182]	validation_0-auc:0.856671
# [183]	validation_0-auc:0.856801
# [184]	validation_0-auc:0.85693
# [185]	validation_0-auc:0.857166
# [186]	validation_0-auc:0.857219
# [187]	validation_0-auc:0.857312
# [188]	validation_0-auc:0.857365
# [189]	validation_0-auc:0.857428
# [190]	validation_0-auc:0.857538
# [191]	validation_0-auc:0.85769
# [192]	validation_0-auc:0.857839
# [193]	validation_0-auc:0.857958
# [194]	validation_0-auc:0.858128
# [195]	validation_0-auc:0.858226
# [196]	validation_0-auc:0.858259
# [197]	validation_0-auc:0.858305
# [198]	validation_0-auc:0.858359
# [199]	validation_0-auc:0.858435
# [200]	validation_0-auc:0.858484
# [201]	validation_0-auc:0.858616
# [202]	validation_0-auc:0.858787
# [203]	validation_0-auc:0.858828
# [204]	validation_0-auc:0.858893
# [205]	validation_0-auc:0.858966
# [206]	validation_0-auc:0.859055
# [207]	validation_0-auc:0.859112
# [208]	validation_0-auc:0.859184
# [209]	validation_0-auc:0.859268
# [210]	validation_0-auc:0.85934
# [211]	validation_0-auc:0.859469
# [212]	validation_0-auc:0.859514
# [213]	validation_0-auc:0.85966
# [214]	validation_0-auc:0.859804
# [215]	validation_0-auc:0.85998
# [216]	validation_0-auc:0.860066
# [217]	validation_0-auc:0.860143
# [218]	validation_0-auc:0.860269
# [219]	validation_0-auc:0.86043
# [220]	validation_0-auc:0.860401
# [221]	validation_0-auc:0.860431
# [222]	validation_0-auc:0.860588
# [223]	validation_0-auc:0.86069
# [224]	validation_0-auc:0.860756
# [225]	validation_0-auc:0.860874
# [226]	validation_0-auc:0.860951
# [227]	validation_0-auc:0.860946
# [228]	validation_0-auc:0.861003
# [229]	validation_0-auc:0.861049
# [230]	validation_0-auc:0.861089
# [231]	validation_0-auc:0.86123
# [232]	validation_0-auc:0.861294
# [233]	validation_0-auc:0.861338
# [234]	validation_0-auc:0.861451
# [235]	validation_0-auc:0.861526
# [236]	validation_0-auc:0.861599
# [237]	validation_0-auc:0.861681
# [238]	validation_0-auc:0.861729
# [239]	validation_0-auc:0.861858
# [240]	validation_0-auc:0.861929
# [241]	validation_0-auc:0.862101
# [242]	validation_0-auc:0.862238
# [243]	validation_0-auc:0.862299
# [244]	validation_0-auc:0.862468
# [245]	validation_0-auc:0.862566
# [246]	validation_0-auc:0.8626
# [247]	validation_0-auc:0.862728
# [248]	validation_0-auc:0.862819
# [249]	validation_0-auc:0.862819
# [250]	validation_0-auc:0.862885
# [251]	validation_0-auc:0.863014
# [252]	validation_0-auc:0.863101
# [253]	validation_0-auc:0.86318
# [254]	validation_0-auc:0.863223
# [255]	validation_0-auc:0.863297
# [256]	validation_0-auc:0.863409
# [257]	validation_0-auc:0.863537
# [258]	validation_0-auc:0.863573
# [259]	validation_0-auc:0.863645
# [260]	validation_0-auc:0.863746
# [261]	validation_0-auc:0.863746
# [262]	validation_0-auc:0.863907
# [263]	validation_0-auc:0.864001
# [264]	validation_0-auc:0.864101
# [265]	validation_0-auc:0.864146
# [266]	validation_0-auc:0.864214
# [267]	validation_0-auc:0.864191
# [268]	validation_0-auc:0.864357
# [269]	validation_0-auc:0.864497
# [270]	validation_0-auc:0.864611
# [271]	validation_0-auc:0.864665
# [272]	validation_0-auc:0.864763
# [273]	validation_0-auc:0.864749
# [274]	validation_0-auc:0.864831
# [275]	validation_0-auc:0.865005
# [276]	validation_0-auc:0.865083
# [277]	validation_0-auc:0.865179
# [278]	validation_0-auc:0.865254
# [279]	validation_0-auc:0.865371
# [280]	validation_0-auc:0.865484
# [281]	validation_0-auc:0.865505
# [282]	validation_0-auc:0.865563
# [283]	validation_0-auc:0.865564
# [284]	validation_0-auc:0.865705
# [285]	validation_0-auc:0.865856
# [286]	validation_0-auc:0.865885
# [287]	validation_0-auc:0.865984
# [288]	validation_0-auc:0.866041
# [289]	validation_0-auc:0.866124
# [290]	validation_0-auc:0.866099
# [291]	validation_0-auc:0.866135
# [292]	validation_0-auc:0.866234
# [293]	validation_0-auc:0.866342
# [294]	validation_0-auc:0.866395
# [295]	validation_0-auc:0.866466
# [296]	validation_0-auc:0.866475
# [297]	validation_0-auc:0.86652
# [298]	validation_0-auc:0.866536
# [299]	validation_0-auc:0.866649
# [300]	validation_0-auc:0.866735
# [301]	validation_0-auc:0.866813
# [302]	validation_0-auc:0.866792
# [303]	validation_0-auc:0.866895
# [304]	validation_0-auc:0.866901
# [305]	validation_0-auc:0.866918
# [306]	validation_0-auc:0.866919
# [307]	validation_0-auc:0.866947
# [308]	validation_0-auc:0.867022
# [309]	validation_0-auc:0.867111
# [310]	validation_0-auc:0.867209
# [311]	validation_0-auc:0.867267
# [312]	validation_0-auc:0.867292
# [313]	validation_0-auc:0.867353
# [314]	validation_0-auc:0.867472
# [315]	validation_0-auc:0.867497
# [316]	validation_0-auc:0.867474
# [317]	validation_0-auc:0.867524
# [318]	validation_0-auc:0.86751
# [319]	validation_0-auc:0.867552
# [320]	validation_0-auc:0.867594
# [321]	validation_0-auc:0.86769
# [322]	validation_0-auc:0.867784
# [323]	validation_0-auc:0.867861
# [324]	validation_0-auc:0.867909
# [325]	validation_0-auc:0.867985
# [326]	validation_0-auc:0.868042
# [327]	validation_0-auc:0.868151
# [328]	validation_0-auc:0.868268
# [329]	validation_0-auc:0.868264
# [330]	validation_0-auc:0.868315
# [331]	validation_0-auc:0.868392
# [332]	validation_0-auc:0.86849
# [333]	validation_0-auc:0.868529
# [334]	validation_0-auc:0.868563
# [335]	validation_0-auc:0.868617
# [336]	validation_0-auc:0.868656
# [337]	validation_0-auc:0.868728
# [338]	validation_0-auc:0.868744
# [339]	validation_0-auc:0.868749
# [340]	validation_0-auc:0.868867
# [341]	validation_0-auc:0.868917
# [342]	validation_0-auc:0.868911
# [343]	validation_0-auc:0.869045
# [344]	validation_0-auc:0.869063
# [345]	validation_0-auc:0.869091
# [346]	validation_0-auc:0.869196
# [347]	validation_0-auc:0.869205
# [348]	validation_0-auc:0.869241
# [349]	validation_0-auc:0.869284
# [350]	validation_0-auc:0.869356
# [351]	validation_0-auc:0.869425
# [352]	validation_0-auc:0.869448
# [353]	validation_0-auc:0.869448
# [354]	validation_0-auc:0.86948
# [355]	validation_0-auc:0.86957
# [356]	validation_0-auc:0.869644
# [357]	validation_0-auc:0.869683
# [358]	validation_0-auc:0.869716
# [359]	validation_0-auc:0.869724
# [360]	validation_0-auc:0.869775
# [361]	validation_0-auc:0.869841
# [362]	validation_0-auc:0.869881
# [363]	validation_0-auc:0.869938
# [364]	validation_0-auc:0.870015
# [365]	validation_0-auc:0.870071
# [366]	validation_0-auc:0.870073
# [367]	validation_0-auc:0.870105
# [368]	validation_0-auc:0.870188
# [369]	validation_0-auc:0.870235
# [370]	validation_0-auc:0.870344
# [371]	validation_0-auc:0.870418
# [372]	validation_0-auc:0.870503
# [373]	validation_0-auc:0.870568
# [374]	validation_0-auc:0.870656
# [375]	validation_0-auc:0.870701
# [376]	validation_0-auc:0.870758
# [377]	validation_0-auc:0.870772
# [378]	validation_0-auc:0.870799
# [379]	validation_0-auc:0.870901
# [380]	validation_0-auc:0.870996
# [381]	validation_0-auc:0.871031
# [382]	validation_0-auc:0.871049
# [383]	validation_0-auc:0.8711
# [384]	validation_0-auc:0.871127
# [385]	validation_0-auc:0.871172
# [386]	validation_0-auc:0.871257
# [387]	validation_0-auc:0.87126
# [388]	validation_0-auc:0.87128
# [389]	validation_0-auc:0.871364
# [390]	validation_0-auc:0.871481
# [391]	validation_0-auc:0.871464
# [392]	validation_0-auc:0.871509
# [393]	validation_0-auc:0.871601
# [394]	validation_0-auc:0.871704
# [395]	validation_0-auc:0.871746
# [396]	validation_0-auc:0.871805
# [397]	validation_0-auc:0.871814
# [398]	validation_0-auc:0.871804
# [399]	validation_0-auc:0.871814
# [400]	validation_0-auc:0.87185
# [401]	validation_0-auc:0.871882
# [402]	validation_0-auc:0.87187
# [403]	validation_0-auc:0.871928
# [404]	validation_0-auc:0.871941
# [405]	validation_0-auc:0.871927
# [406]	validation_0-auc:0.871941
# [407]	validation_0-auc:0.872059
# [408]	validation_0-auc:0.872098
# [409]	validation_0-auc:0.872173
# [410]	validation_0-auc:0.872283
# [411]	validation_0-auc:0.872338
# [412]	validation_0-auc:0.872419
# [413]	validation_0-auc:0.872437
# [414]	validation_0-auc:0.872482
# [415]	validation_0-auc:0.872556
# [416]	validation_0-auc:0.87268
# [417]	validation_0-auc:0.872729
# [418]	validation_0-auc:0.872769
# [419]	validation_0-auc:0.872809
# [420]	validation_0-auc:0.872849
# [421]	validation_0-auc:0.872924
# [422]	validation_0-auc:0.872933
# [423]	validation_0-auc:0.873021
# [424]	validation_0-auc:0.873036
# [425]	validation_0-auc:0.873055
# [426]	validation_0-auc:0.873108
# [427]	validation_0-auc:0.873186
# [428]	validation_0-auc:0.873246
# [429]	validation_0-auc:0.873261
# [430]	validation_0-auc:0.873326
# [431]	validation_0-auc:0.873325
# [432]	validation_0-auc:0.873358
# [433]	validation_0-auc:0.873406
# [434]	validation_0-auc:0.873514
# [435]	validation_0-auc:0.873548
# [436]	validation_0-auc:0.873627
# [437]	validation_0-auc:0.873733
# [438]	validation_0-auc:0.873754
# [439]	validation_0-auc:0.87375
# [440]	validation_0-auc:0.873795
# [441]	validation_0-auc:0.873914
# [442]	validation_0-auc:0.874014
# [443]	validation_0-auc:0.874044
# [444]	validation_0-auc:0.874071
# [445]	validation_0-auc:0.874085
# [446]	validation_0-auc:0.874092
# [447]	validation_0-auc:0.874183
# [448]	validation_0-auc:0.874208
# [449]	validation_0-auc:0.874296
# [450]	validation_0-auc:0.874329
# [451]	validation_0-auc:0.874434
# [452]	validation_0-auc:0.874488
# [453]	validation_0-auc:0.874554
# [454]	validation_0-auc:0.874557
# [455]	validation_0-auc:0.87458
# [456]	validation_0-auc:0.874598
# [457]	validation_0-auc:0.874655
# [458]	validation_0-auc:0.874662
# [459]	validation_0-auc:0.874682
# [460]	validation_0-auc:0.874793
# [461]	validation_0-auc:0.874841
# [462]	validation_0-auc:0.874849
# [463]	validation_0-auc:0.874922
# [464]	validation_0-auc:0.874991
# [465]	validation_0-auc:0.875081
# [466]	validation_0-auc:0.875139
# [467]	validation_0-auc:0.875237
# [468]	validation_0-auc:0.875374
# [469]	validation_0-auc:0.875414
# [470]	validation_0-auc:0.875442
# [471]	validation_0-auc:0.875555
# [472]	validation_0-auc:0.875574
# [473]	validation_0-auc:0.875636
# [474]	validation_0-auc:0.875661
# [475]	validation_0-auc:0.875679
# [476]	validation_0-auc:0.875778
# [477]	validation_0-auc:0.875815
# [478]	validation_0-auc:0.875821
# [479]	validation_0-auc:0.875834
# [480]	validation_0-auc:0.875889
# [481]	validation_0-auc:0.875994
# [482]	validation_0-auc:0.876012
# [483]	validation_0-auc:0.87607
# [484]	validation_0-auc:0.876093
# [485]	validation_0-auc:0.87617
# [486]	validation_0-auc:0.876171
# [487]	validation_0-auc:0.876163
# [488]	validation_0-auc:0.876277
# [489]	validation_0-auc:0.876334
# [490]	validation_0-auc:0.876392
# [491]	validation_0-auc:0.876452
# [492]	validation_0-auc:0.87647
# [493]	validation_0-auc:0.876459
# [494]	validation_0-auc:0.876444
# [495]	validation_0-auc:0.876463
# [496]	validation_0-auc:0.876481
# [497]	validation_0-auc:0.876554
# [498]	validation_0-auc:0.876657
# [499]	validation_0-auc:0.876681
# XGBClassifier(base_score=0.5, colsample_bylevel=0.7, colsample_bytree=1.0,
#        gamma=1.0, learning_rate=0.02, max_delta_step=0, max_depth=5,
#        min_child_weight=5, missing=-999.0, n_estimators=500, nthread=-1,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=123089, silent=True, subsample=0.8)

# %%
print('Overall AUC:', roc_auc_score(y_train, clf.predict_proba(X_train)[:,1]))
# Out:
# ('Overall AUC:', 0.87886365774350472)

# %%
# predicting
y_pred= clf.predict_proba(X_test)[:,1]

# %%
submission = pd.DataFrame(data=y_pred)
submission.to_csv("submission.csv", index=False, header=None)
