# %%
from __future__ import division

# import matplotlib.pyplot as plt
from collections import Counter
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.svm import OneClassSVM
from sklearn.model_selection import GridSearchCV
# Out:
# /home/labamn/miniconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
df_train = pd.read_csv('new_train.csv')

# %%
print (Counter(df_train['TARGET']))
# Out:
# Counter({0: 57665, 1: 2355})

# %%
names = df_train.columns.values.tolist()[:-1]

# %%
df_test = pd.read_csv('test.csv', names=names)

# %%
# process base
def process_base(train, test):
    train.loc[(train['var38']>117310.979) & (train['var38']<117310.98), 'var38'] = -999.0
    test.loc[(test['var38']>117310.979) & (test['var38']<117310.98), 'var38'] = -999.0

    train.loc[train['var3']==-999999, 'var3'] = -999.0
    test.loc[test['var3']==-999999, 'var3'] = -999.0

    for f in ['imp_op_var40_comer_ult1', 'imp_op_var40_efect_ult3', 'imp_op_var41_comer_ult3', 'imp_sal_var16_ult1']:
        train.loc[train[f]==0.0, f] = -999.0
        test.loc[test[f]==0.0, f] = -999.0
        
    return train, test

# %%
df_train, df_test = process_base(df_train, df_test)

# %%
# remove constant columns
remove = []
for col in df_train.columns:
    if df_train[col].std() == 0:
        remove.append(col)

df_train.drop(remove, axis=1, inplace=True)
df_test.drop(remove, axis=1, inplace=True)

# %%
# remove duplicated columns
remove = []
c = df_train.columns
for i in range(len(c)-1):
    v = df_train[c[i]].values
    for j in range(i+1,len(c)):
        if np.array_equal(v,df_train[c[j]].values):
            remove.append(c[j])
df_train.drop(remove, axis=1, inplace=True)
df_test.drop(remove, axis=1, inplace=True)

# %%
# insert sum zeros feature
flist = [x for x in df_train.columns if not x in ['ID','TARGET']]
df_train.insert(1, 'SumZeros', (df_train[flist] == 0).astype(int).sum(axis=1))
df_test.insert(1, 'SumZeros', (df_test[flist] == 0).astype(int).sum(axis=1))

# %%
def normalize_features(train, test):
    flist = [x for x in train.columns if not x in ['ID','TARGET']]
    for f in flist:
        if train[f].max() == 9999999999.0:
            fmax = train.loc[train[f]<9999999999.0, f].max()
            train.loc[train[f]==9999999999.0, f] = fmax + 1

        if len(train.loc[train[f]<0, f].value_counts()) == 1:
            train.loc[train[f]<0, f] = -1.0
            test.loc[test[f]<0, f] = -1.0
            fmax = max(np.max(train[f]), np.max(test[f]))
            if fmax > 0:
                train.loc[train[f]>0, f] = 1.0*train.loc[train[f]>0, f]/fmax
                test.loc[test[f]>0, f] = 1.0*test.loc[test[f]>0, f]/fmax

        if len(train.loc[train[f]<0, f]) == 0:
            fmax = max(np.max(train[f]), np.max(test[f]))
            if fmax > 0:
                train.loc[train[f]>0, f] = 1.0*train.loc[train[f]>0, f]/fmax
                test.loc[test[f]>0, f] = 1.0*test.loc[test[f]>0, f]/fmax

        if len(train.loc[train[f]<0, f].value_counts()) > 1:
            fmax = max(np.max(train[f]), np.max(test[f]))
            if fmax > 0:
                train[f] = 1.0*train[f]/fmax
                test[f] = 1.0*test[f]/fmax

    return train, test

# %%
df_train, df_test = normalize_features(df_train, df_test)

# %%
# from sklearn.decomposition import PCA

# pca = PCA(n_components=2)
# x_train_projected = pca.fit_transform(df_train.drop(['TARGET'], axis=1).values)
# x_test_projected = pca.transform(df_test.values)
# df_train.insert(1, 'PCAOne', x_train_projected[:, 0])
# df_train.insert(1, 'PCATwo', x_train_projected[:, 1])
# df_test.insert(1, 'PCAOne', x_test_projected[:, 0])
# df_test.insert(1, 'PCATwo', x_test_projected[:, 1])

# %%
# from sklearn.manifold import TSNE
# from sklearn.decomposition import TruncatedSVD
# from sklearn.preprocessing import StandardScaler

# X = df_train.drop(['TARGET'], axis=1).append(df_test).values
# svd = TruncatedSVD(n_components=30)

# len_train = df_train.values.shape[0]

# X_svd = svd.fit_transform(X)
# X_scaled = StandardScaler().fit_transform(X_svd)
# modelTSNE = TSNE(n_components=2,random_state=0)
# feats_tsne = modelTSNE.fit_transform(X_scaled)
# feats_tsne_train = pd.DataFrame(feats_tsne[:len_train], columns=['tsne1', 'tsne2'])
# feats_tsne_test = pd.DataFrame(feats_tsne[len_train:], columns=['tsne1', 'tsne2'])
# # feats_tsne['ID'] = train[['ID']].append(test[['ID']], ignore_index=True)['ID'].values
# df_train = pd.merge(train, feats_tsne, on='ID', how='left')
# df_test = pd.merge(test, feats_tsne, on='ID', how='left')


# # tsne = TSNE(n_components=2)

# %%
# add K-means features

from sklearn.cluster import KMeans

# flist = [x for x in train.columns if not x in ['ID','TARGET']]

flist_kmeans = []
for ncl in range(2,11):
    cls = KMeans(n_clusters=ncl)
    cls.fit_predict(df_train[flist].values)
    df_train['kmeans_cluster'+str(ncl)] = cls.predict(df_train[flist].values)
    df_test['kmeans_cluster'+str(ncl)] = cls.predict(df_test[flist].values)
    flist_kmeans.append('kmeans_cluster'+str(ncl))

# %%
y_train = df_train['TARGET'].values
X_train = df_train.drop(['TARGET'], axis=1).values

X_test = df_test.values

# length of dataset
len_train = len(X_train)
len_test  = len(X_test)

# %%
# from sklearn.ensemble import ExtraTreesClassifier
# from sklearn.feature_selection import SelectFromModel

# clf_ = ExtraTreesClassifier(n_estimators=1000, n_jobs=-1)
# clf_ = clf_.fit(X_train, y_train)
# model = SelectFromModel(clf_, prefit=True)
# X_new_train = model.transform(X_train)
# X_new_test = model.transform(X_test)

# %%
# print (X_new_train.shape)
# Out:
# (60020, 39)

# %%
# classifier
# clf = xgb.XGBClassifier(missing=-999.0, max_depth=5, min_child_weight=5,
#                         n_estimators=500, learning_rate=0.02, gamma=1.0, 
#                         nthread=-1, subsample=0.8, colsample_bytree=1.0, colsample_bylevel=0.7, seed=123089)

X_fit, X_eval, y_fit, y_eval= train_test_split(X_train, y_train, test_size=0.3)

clfEns = []

for seed in [123089, 21324, 324003, 450453, 120032]:
    clfEns.append( xgb.XGBClassifier(missing=-999.0, max_depth=5, min_child_weight=5,
                        n_estimators=750, learning_rate=0.02, gamma=1.0, 
                        nthread=-1, subsample=0.8, colsample_bytree=1.0, colsample_bylevel=0.7, seed=seed) )

# %%
# param_test1 = {
# #     'max_depth':range(1,10,1),
# #     'min_child_weight':[1,2],
#     'gamma':[0.0, 0.05, 0.25, 0.75],
# #     'subsample':[0.75, 0.95],
# #     'colsample_bytree':[0.75,0.95],
# #     'reg_alpha':[0, 0.01],
#     'learning_rate':[0.003, 0.01, 0.03, 0.1, 0.3]
# }

# %%
# gsearch1 = GridSearchCV(estimator=xgb.sklearn.XGBClassifier(missing=np.nan, max_depth=5,
#                         min_child_weight=1,objective= 'binary:logistic', gamma=0,
#                         scale_pos_weight=1, n_estimators=350, learning_rate=0.03, 
#                         nthread=-1, subsample=0.95, colsample_bytree=0.85, seed=4242), 
# param_grid = param_test1, scoring='roc_auc',iid=False, verbose=30, n_jobs=-1, cv=5)

# %%
# gsearch1.fit(X_train, y_train)
# # print 'cv_results', gsearch1.cv_results_
# print ('\n')
# print ('best parameters', gsearch1.best_params_ )
# print ('best_score', gsearch1.best_score_)

# %%
# fitting
for clf in clfEns:
    clf.fit(X_train, y_train, early_stopping_rounds=20, eval_metric="auc", eval_set=[(X_eval, y_eval)])
# Out:
# [0]	validation_0-auc:0.803313
# Will train until validation_0-auc hasn't improved in 20 rounds.
# [1]	validation_0-auc:0.809813
# [2]	validation_0-auc:0.811366
# [3]	validation_0-auc:0.821103
# [4]	validation_0-auc:0.823587
# [5]	validation_0-auc:0.824871
# [6]	validation_0-auc:0.826172
# [7]	validation_0-auc:0.827442
# [8]	validation_0-auc:0.826984
# [9]	validation_0-auc:0.827018
# [10]	validation_0-auc:0.828351
# [11]	validation_0-auc:0.827926
# [12]	validation_0-auc:0.827581
# [13]	validation_0-auc:0.828109
# [14]	validation_0-auc:0.828038
# [15]	validation_0-auc:0.828409
# [16]	validation_0-auc:0.828437
# [17]	validation_0-auc:0.828051
# [18]	validation_0-auc:0.828968
# [19]	validation_0-auc:0.82917
# [20]	validation_0-auc:0.830112
# [21]	validation_0-auc:0.829944
# [22]	validation_0-auc:0.830157
# [23]	validation_0-auc:0.830641
# [24]	validation_0-auc:0.830922
# [25]	validation_0-auc:0.831197
# [26]	validation_0-auc:0.831235
# [27]	validation_0-auc:0.831626
# [28]	validation_0-auc:0.83184
# [29]	validation_0-auc:0.832297
# [30]	validation_0-auc:0.832061
# [31]	validation_0-auc:0.831409
# [32]	validation_0-auc:0.831412
# [33]	validation_0-auc:0.831592
# [34]	validation_0-auc:0.832118
# [35]	validation_0-auc:0.8325
# [36]	validation_0-auc:0.832264
# [37]	validation_0-auc:0.832261
# [38]	validation_0-auc:0.832723
# [39]	validation_0-auc:0.833144
# [40]	validation_0-auc:0.833319
# [41]	validation_0-auc:0.833915
# [42]	validation_0-auc:0.834256
# [43]	validation_0-auc:0.834131
# [44]	validation_0-auc:0.834484
# [45]	validation_0-auc:0.834507
# [46]	validation_0-auc:0.834634
# [47]	validation_0-auc:0.834756
# [48]	validation_0-auc:0.834692
# [49]	validation_0-auc:0.834991
# [50]	validation_0-auc:0.835036
# [51]	validation_0-auc:0.834797
# [52]	validation_0-auc:0.834726
# [53]	validation_0-auc:0.834862
# [54]	validation_0-auc:0.835123
# [55]	validation_0-auc:0.835406
# [56]	validation_0-auc:0.835361
# [57]	validation_0-auc:0.835214
# [58]	validation_0-auc:0.835717
# [59]	validation_0-auc:0.835707
# [60]	validation_0-auc:0.835984
# [61]	validation_0-auc:0.836133
# [62]	validation_0-auc:0.836802
# [63]	validation_0-auc:0.83663
# [64]	validation_0-auc:0.836684
# [65]	validation_0-auc:0.837535
# [66]	validation_0-auc:0.837514
# [67]	validation_0-auc:0.837731
# [68]	validation_0-auc:0.837901
# [69]	validation_0-auc:0.838059
# [70]	validation_0-auc:0.838727
# [71]	validation_0-auc:0.838848
# [72]	validation_0-auc:0.839217
# [73]	validation_0-auc:0.839153
# [74]	validation_0-auc:0.839297
# [75]	validation_0-auc:0.839328
# [76]	validation_0-auc:0.839691
# [77]	validation_0-auc:0.839855
# [78]	validation_0-auc:0.840117
# [79]	validation_0-auc:0.840221
# [80]	validation_0-auc:0.840831
# [81]	validation_0-auc:0.841033
# [82]	validation_0-auc:0.841026
# [83]	validation_0-auc:0.841168
# [84]	validation_0-auc:0.841452
# [85]	validation_0-auc:0.841542
# [86]	validation_0-auc:0.841876
# [87]	validation_0-auc:0.842029
# [88]	validation_0-auc:0.842101
# [89]	validation_0-auc:0.842263
# [90]	validation_0-auc:0.842409
# [91]	validation_0-auc:0.842548
# [92]	validation_0-auc:0.842709
# [93]	validation_0-auc:0.842783
# [94]	validation_0-auc:0.842758
# [95]	validation_0-auc:0.842854
# [96]	validation_0-auc:0.843015
# [97]	validation_0-auc:0.843042
# [98]	validation_0-auc:0.84319
# [99]	validation_0-auc:0.843165
# [100]	validation_0-auc:0.84348
# [101]	validation_0-auc:0.843611
# [102]	validation_0-auc:0.843689
# [103]	validation_0-auc:0.843792
# [104]	validation_0-auc:0.843762
# [105]	validation_0-auc:0.843868
# [106]	validation_0-auc:0.844067
# [107]	validation_0-auc:0.844217
# [108]	validation_0-auc:0.844305
# [109]	validation_0-auc:0.844367
# [110]	validation_0-auc:0.844451
# [111]	validation_0-auc:0.8445
# [112]	validation_0-auc:0.844703
# [113]	validation_0-auc:0.844934
# [114]	validation_0-auc:0.845037
# [115]	validation_0-auc:0.845157
# [116]	validation_0-auc:0.845333
# [117]	validation_0-auc:0.845479
# [118]	validation_0-auc:0.845579
# [119]	validation_0-auc:0.845619
# [120]	validation_0-auc:0.845758
# [121]	validation_0-auc:0.845954
# [122]	validation_0-auc:0.846077
# [123]	validation_0-auc:0.846232
# [124]	validation_0-auc:0.846397
# [125]	validation_0-auc:0.846604
# [126]	validation_0-auc:0.846739
# [127]	validation_0-auc:0.846943
# [128]	validation_0-auc:0.847085
# [129]	validation_0-auc:0.847222
# [130]	validation_0-auc:0.847381
# [131]	validation_0-auc:0.847576
# [132]	validation_0-auc:0.847802
# [133]	validation_0-auc:0.847962
# [134]	validation_0-auc:0.848088
# [135]	validation_0-auc:0.848207
# [136]	validation_0-auc:0.848205
# [137]	validation_0-auc:0.848362
# [138]	validation_0-auc:0.848468
# [139]	validation_0-auc:0.848499
# [140]	validation_0-auc:0.848673
# [141]	validation_0-auc:0.848754
# [142]	validation_0-auc:0.84899
# [143]	validation_0-auc:0.849053
# [144]	validation_0-auc:0.849116
# [145]	validation_0-auc:0.849273
# [146]	validation_0-auc:0.849527
# [147]	validation_0-auc:0.849657
# [148]	validation_0-auc:0.849649
# [149]	validation_0-auc:0.849796
# [150]	validation_0-auc:0.850103
# [151]	validation_0-auc:0.850213
# [152]	validation_0-auc:0.850488
# [153]	validation_0-auc:0.850568
# [154]	validation_0-auc:0.850631
# [155]	validation_0-auc:0.850798
# [156]	validation_0-auc:0.850865
# [157]	validation_0-auc:0.85102
# [158]	validation_0-auc:0.851272
# [159]	validation_0-auc:0.851397
# [160]	validation_0-auc:0.851544
# [161]	validation_0-auc:0.851709
# [162]	validation_0-auc:0.85183
# [163]	validation_0-auc:0.852017
# [164]	validation_0-auc:0.852188
# [165]	validation_0-auc:0.852316
# [166]	validation_0-auc:0.852496
# [167]	validation_0-auc:0.852503
# [168]	validation_0-auc:0.852689
# [169]	validation_0-auc:0.852818
# [170]	validation_0-auc:0.852929
# [171]	validation_0-auc:0.85295
# [172]	validation_0-auc:0.853054
# [173]	validation_0-auc:0.853156
# [174]	validation_0-auc:0.85328
# [175]	validation_0-auc:0.853413
# [176]	validation_0-auc:0.853572
# [177]	validation_0-auc:0.853724
# [178]	validation_0-auc:0.853817
# [179]	validation_0-auc:0.853921
# [180]	validation_0-auc:0.853997
# [181]	validation_0-auc:0.854047
# [182]	validation_0-auc:0.854085
# [183]	validation_0-auc:0.8542
# [184]	validation_0-auc:0.854366
# [185]	validation_0-auc:0.854536
# [186]	validation_0-auc:0.854667
# [187]	validation_0-auc:0.854709
# [188]	validation_0-auc:0.854806
# [189]	validation_0-auc:0.854977
# [190]	validation_0-auc:0.855053
# [191]	validation_0-auc:0.855035
# [192]	validation_0-auc:0.855113
# [193]	validation_0-auc:0.855263
# [194]	validation_0-auc:0.855387
# [195]	validation_0-auc:0.855522
# [196]	validation_0-auc:0.855676
# [197]	validation_0-auc:0.855747
# [198]	validation_0-auc:0.855887
# [199]	validation_0-auc:0.856039
# [200]	validation_0-auc:0.855995
# [201]	validation_0-auc:0.856246
# [202]	validation_0-auc:0.856382
# [203]	validation_0-auc:0.856421
# [204]	validation_0-auc:0.856527
# [205]	validation_0-auc:0.856585
# [206]	validation_0-auc:0.856645
# [207]	validation_0-auc:0.856807
# [208]	validation_0-auc:0.856875
# [209]	validation_0-auc:0.856921
# [210]	validation_0-auc:0.857057
# [211]	validation_0-auc:0.857112
# [212]	validation_0-auc:0.85717
# [213]	validation_0-auc:0.857242
# [214]	validation_0-auc:0.857294
# [215]	validation_0-auc:0.857354
# [216]	validation_0-auc:0.857481
# [217]	validation_0-auc:0.857585
# [218]	validation_0-auc:0.857726
# [219]	validation_0-auc:0.857849
# [220]	validation_0-auc:0.857901
# [221]	validation_0-auc:0.858049
# [222]	validation_0-auc:0.858096
# [223]	validation_0-auc:0.858194
# [224]	validation_0-auc:0.85847
# [225]	validation_0-auc:0.858585
# [226]	validation_0-auc:0.858676
# [227]	validation_0-auc:0.858728
# [228]	validation_0-auc:0.858784
# [229]	validation_0-auc:0.858858
# [230]	validation_0-auc:0.858956
# [231]	validation_0-auc:0.859053
# [232]	validation_0-auc:0.859183
# [233]	validation_0-auc:0.859246
# [234]	validation_0-auc:0.859362
# [235]	validation_0-auc:0.859425
# [236]	validation_0-auc:0.859468
# [237]	validation_0-auc:0.859589
# [238]	validation_0-auc:0.859707
# [239]	validation_0-auc:0.859763
# [240]	validation_0-auc:0.859759
# [241]	validation_0-auc:0.859848
# [242]	validation_0-auc:0.859979
# [243]	validation_0-auc:0.860081
# [244]	validation_0-auc:0.860192
# [245]	validation_0-auc:0.860324
# [246]	validation_0-auc:0.860371
# [247]	validation_0-auc:0.860413
# [248]	validation_0-auc:0.860411
# [249]	validation_0-auc:0.860511
# [250]	validation_0-auc:0.860517
# [251]	validation_0-auc:0.860583
# [252]	validation_0-auc:0.860696
# [253]	validation_0-auc:0.860752
# [254]	validation_0-auc:0.860979
# [255]	validation_0-auc:0.861068
# [256]	validation_0-auc:0.861142
# [257]	validation_0-auc:0.86122
# [258]	validation_0-auc:0.861223
# [259]	validation_0-auc:0.86127
# [260]	validation_0-auc:0.861366
# [261]	validation_0-auc:0.861413
# [262]	validation_0-auc:0.861514
# [263]	validation_0-auc:0.861534
# [264]	validation_0-auc:0.861633
# [265]	validation_0-auc:0.861766
# [266]	validation_0-auc:0.861893
# [267]	validation_0-auc:0.86202
# [268]	validation_0-auc:0.862093
# [269]	validation_0-auc:0.8622
# [270]	validation_0-auc:0.862279
# [271]	validation_0-auc:0.8624
# [272]	validation_0-auc:0.86245
# [273]	validation_0-auc:0.862482
# [274]	validation_0-auc:0.862477
# [275]	validation_0-auc:0.862543
# [276]	validation_0-auc:0.862622
# [277]	validation_0-auc:0.862742
# [278]	validation_0-auc:0.862856
# [279]	validation_0-auc:0.8629
# [280]	validation_0-auc:0.862971
# [281]	validation_0-auc:0.863147
# [282]	validation_0-auc:0.863158
# [283]	validation_0-auc:0.863173
# [284]	validation_0-auc:0.863215
# [285]	validation_0-auc:0.863351
# [286]	validation_0-auc:0.863421
# [287]	validation_0-auc:0.863447
# [288]	validation_0-auc:0.863572
# [289]	validation_0-auc:0.863663
# [290]	validation_0-auc:0.863713
# [291]	validation_0-auc:0.86376
# [292]	validation_0-auc:0.863802
# [293]	validation_0-auc:0.863943
# [294]	validation_0-auc:0.864037
# [295]	validation_0-auc:0.864072
# [296]	validation_0-auc:0.864152
# [297]	validation_0-auc:0.864236
# [298]	validation_0-auc:0.864304
# [299]	validation_0-auc:0.864413
# [300]	validation_0-auc:0.864479
# [301]	validation_0-auc:0.864568
# [302]	validation_0-auc:0.864688
# [303]	validation_0-auc:0.864731
# [304]	validation_0-auc:0.864786
# [305]	validation_0-auc:0.864941
# [306]	validation_0-auc:0.864997
# [307]	validation_0-auc:0.865058
# [308]	validation_0-auc:0.865183
# [309]	validation_0-auc:0.865269
# [310]	validation_0-auc:0.86532
# [311]	validation_0-auc:0.865399
# [312]	validation_0-auc:0.865566
# [313]	validation_0-auc:0.865634
# [314]	validation_0-auc:0.865744
# [315]	validation_0-auc:0.865748
# [316]	validation_0-auc:0.865798
# [317]	validation_0-auc:0.865896
# [318]	validation_0-auc:0.86601
# [319]	validation_0-auc:0.866077
# [320]	validation_0-auc:0.866054
# [321]	validation_0-auc:0.866088
# [322]	validation_0-auc:0.866194
# [323]	validation_0-auc:0.866237
# [324]	validation_0-auc:0.866239
# [325]	validation_0-auc:0.866293
# [326]	validation_0-auc:0.866425
# [327]	validation_0-auc:0.866441
# [328]	validation_0-auc:0.86646
# [329]	validation_0-auc:0.866473
# [330]	validation_0-auc:0.866512
# [331]	validation_0-auc:0.866593
# [332]	validation_0-auc:0.866651
# [333]	validation_0-auc:0.866638
# [334]	validation_0-auc:0.866645
# [335]	validation_0-auc:0.86676
# [336]	validation_0-auc:0.866806
# [337]	validation_0-auc:0.866879
# [338]	validation_0-auc:0.866962
# [339]	validation_0-auc:0.867004
# [340]	validation_0-auc:0.867043
# [341]	validation_0-auc:0.867082
# [342]	validation_0-auc:0.867153
# [343]	validation_0-auc:0.867226
# [344]	validation_0-auc:0.867266
# [345]	validation_0-auc:0.867386
# [346]	validation_0-auc:0.86743
# [347]	validation_0-auc:0.867462
# [348]	validation_0-auc:0.86746
# [349]	validation_0-auc:0.867523
# [350]	validation_0-auc:0.867607
# [351]	validation_0-auc:0.86765
# [352]	validation_0-auc:0.867684
# [353]	validation_0-auc:0.867778
# [354]	validation_0-auc:0.867863
# [355]	validation_0-auc:0.867936
# [356]	validation_0-auc:0.867964
# [357]	validation_0-auc:0.867996
# [358]	validation_0-auc:0.868062
# [359]	validation_0-auc:0.868169
# [360]	validation_0-auc:0.868219
# [361]	validation_0-auc:0.868283
# [362]	validation_0-auc:0.868312
# [363]	validation_0-auc:0.868349
# [364]	validation_0-auc:0.868408
# [365]	validation_0-auc:0.868405
# [366]	validation_0-auc:0.868427
# [367]	validation_0-auc:0.868457
# [368]	validation_0-auc:0.868528
# [369]	validation_0-auc:0.868584
# [370]	validation_0-auc:0.868623
# [371]	validation_0-auc:0.868731
# [372]	validation_0-auc:0.86882
# [373]	validation_0-auc:0.868913
# [374]	validation_0-auc:0.868929
# [375]	validation_0-auc:0.869027
# [376]	validation_0-auc:0.869083
# [377]	validation_0-auc:0.869095
# [378]	validation_0-auc:0.869109
# [379]	validation_0-auc:0.869147
# [380]	validation_0-auc:0.869164
# [381]	validation_0-auc:0.869189
# [382]	validation_0-auc:0.869187
# [383]	validation_0-auc:0.869263
# [384]	validation_0-auc:0.86934
# [385]	validation_0-auc:0.869367
# [386]	validation_0-auc:0.869386
# [387]	validation_0-auc:0.869451
# [388]	validation_0-auc:0.869458
# [389]	validation_0-auc:0.869465
# [390]	validation_0-auc:0.869475
# [391]	validation_0-auc:0.86949
# [392]	validation_0-auc:0.869521
# [393]	validation_0-auc:0.869595
# [394]	validation_0-auc:0.869686
# [395]	validation_0-auc:0.869699
# [396]	validation_0-auc:0.869729
# [397]	validation_0-auc:0.86974
# [398]	validation_0-auc:0.869801
# [399]	validation_0-auc:0.869823
# [400]	validation_0-auc:0.869847
# [401]	validation_0-auc:0.869903
# [402]	validation_0-auc:0.870054
# [403]	validation_0-auc:0.870087
# [404]	validation_0-auc:0.870143
# [405]	validation_0-auc:0.87015
# [406]	validation_0-auc:0.870194
# [407]	validation_0-auc:0.870206
# [408]	validation_0-auc:0.870248
# [409]	validation_0-auc:0.870367
# [410]	validation_0-auc:0.870375
# [411]	validation_0-auc:0.870393
# [412]	validation_0-auc:0.870505
# [413]	validation_0-auc:0.870519
# [414]	validation_0-auc:0.870577
# [415]	validation_0-auc:0.870589
# [416]	validation_0-auc:0.870619
# [417]	validation_0-auc:0.870718
# [418]	validation_0-auc:0.870767
# [419]	validation_0-auc:0.870827
# [420]	validation_0-auc:0.87086
# [421]	validation_0-auc:0.870868
# [422]	validation_0-auc:0.870886
# [423]	validation_0-auc:0.870928
# [424]	validation_0-auc:0.871023
# [425]	validation_0-auc:0.871053
# [426]	validation_0-auc:0.87112
# [427]	validation_0-auc:0.871166
# [428]	validation_0-auc:0.871238
# [429]	validation_0-auc:0.871338
# [430]	validation_0-auc:0.871402
# [431]	validation_0-auc:0.871474
# [432]	validation_0-auc:0.871602
# [433]	validation_0-auc:0.871629
# [434]	validation_0-auc:0.871654
# [435]	validation_0-auc:0.871684
# [436]	validation_0-auc:0.871693
# [437]	validation_0-auc:0.871706
# [438]	validation_0-auc:0.871733
# [439]	validation_0-auc:0.8718
# [440]	validation_0-auc:0.871986
# [441]	validation_0-auc:0.872043
# [442]	validation_0-auc:0.872108
# [443]	validation_0-auc:0.872214
# [444]	validation_0-auc:0.872295
# [445]	validation_0-auc:0.872396
# [446]	validation_0-auc:0.872498
# [447]	validation_0-auc:0.872536
# [448]	validation_0-auc:0.872548
# [449]	validation_0-auc:0.872585
# [450]	validation_0-auc:0.872577
# [451]	validation_0-auc:0.872653
# [452]	validation_0-auc:0.872732
# [453]	validation_0-auc:0.872747
# [454]	validation_0-auc:0.872763
# [455]	validation_0-auc:0.872842
# [456]	validation_0-auc:0.872906
# [457]	validation_0-auc:0.872916
# [458]	validation_0-auc:0.872953
# [459]	validation_0-auc:0.873005
# [460]	validation_0-auc:0.873029
# [461]	validation_0-auc:0.873038
# [462]	validation_0-auc:0.873053
# [463]	validation_0-auc:0.873073
# [464]	validation_0-auc:0.873111
# [465]	validation_0-auc:0.873142
# [466]	validation_0-auc:0.873197
# [467]	validation_0-auc:0.873225
# [468]	validation_0-auc:0.873322
# [469]	validation_0-auc:0.873375
# [470]	validation_0-auc:0.873392
# [471]	validation_0-auc:0.873423
# [472]	validation_0-auc:0.873451
# [473]	validation_0-auc:0.87349
# [474]	validation_0-auc:0.873574
# [475]	validation_0-auc:0.873634
# [476]	validation_0-auc:0.873718
# [477]	validation_0-auc:0.873794
# [478]	validation_0-auc:0.873849
# [479]	validation_0-auc:0.873906
# [480]	validation_0-auc:0.873993
# [481]	validation_0-auc:0.874006
# [482]	validation_0-auc:0.874075
# [483]	validation_0-auc:0.874097
# [484]	validation_0-auc:0.874134
# [485]	validation_0-auc:0.874181
# [486]	validation_0-auc:0.874345
# [487]	validation_0-auc:0.874488
# [488]	validation_0-auc:0.874516
# [489]	validation_0-auc:0.87463
# [490]	validation_0-auc:0.874641
# [491]	validation_0-auc:0.874657
# [492]	validation_0-auc:0.874703
# [493]	validation_0-auc:0.874783
# [494]	validation_0-auc:0.874805
# [495]	validation_0-auc:0.874824
# [496]	validation_0-auc:0.874904
# [497]	validation_0-auc:0.874961
# [498]	validation_0-auc:0.875006
# [499]	validation_0-auc:0.875032
# [500]	validation_0-auc:0.87509
# [501]	validation_0-auc:0.875145
# [502]	validation_0-auc:0.875166
# [503]	validation_0-auc:0.875196
# [504]	validation_0-auc:0.875231
# [505]	validation_0-auc:0.875321
# [506]	validation_0-auc:0.875339
# [507]	validation_0-auc:0.875373
# [508]	validation_0-auc:0.875442
# [509]	validation_0-auc:0.875522
# [510]	validation_0-auc:0.875559
# [511]	validation_0-auc:0.875609
# [512]	validation_0-auc:0.875652
# [513]	validation_0-auc:0.875749
# [514]	validation_0-auc:0.875793
# [515]	validation_0-auc:0.875882
# [516]	validation_0-auc:0.876005
# [517]	validation_0-auc:0.876026
# [518]	validation_0-auc:0.876053
# [519]	validation_0-auc:0.876068
# [520]	validation_0-auc:0.876107
# [521]	validation_0-auc:0.876165
# [522]	validation_0-auc:0.876196
# [523]	validation_0-auc:0.876276
# [524]	validation_0-auc:0.876363
# [525]	validation_0-auc:0.876395
# [526]	validation_0-auc:0.876459
# [527]	validation_0-auc:0.876461
# [528]	validation_0-auc:0.876556
# [529]	validation_0-auc:0.876628
# [530]	validation_0-auc:0.876728
# [531]	validation_0-auc:0.876745
# [532]	validation_0-auc:0.876764
# [533]	validation_0-auc:0.876824
# [534]	validation_0-auc:0.876854
# [535]	validation_0-auc:0.87695
# [536]	validation_0-auc:0.876978
# [537]	validation_0-auc:0.877
# [538]	validation_0-auc:0.877031
# [539]	validation_0-auc:0.877084
# [540]	validation_0-auc:0.877159
# [541]	validation_0-auc:0.877171
# [542]	validation_0-auc:0.877272
# [543]	validation_0-auc:0.877321
# [544]	validation_0-auc:0.877385
# [545]	validation_0-auc:0.877472
# [546]	validation_0-auc:0.87748
# [547]	validation_0-auc:0.877504
# [548]	validation_0-auc:0.877544
# [549]	validation_0-auc:0.877617
# [550]	validation_0-auc:0.877726
# [551]	validation_0-auc:0.877785
# [552]	validation_0-auc:0.877931
# [553]	validation_0-auc:0.878002
# [554]	validation_0-auc:0.878034
# [555]	validation_0-auc:0.878099
# [556]	validation_0-auc:0.878144
# [557]	validation_0-auc:0.878163
# [558]	validation_0-auc:0.878162
# [559]	validation_0-auc:0.878195
# [560]	validation_0-auc:0.878238
# [561]	validation_0-auc:0.878316
# [562]	validation_0-auc:0.87834
# [563]	validation_0-auc:0.878459
# [564]	validation_0-auc:0.87854
# [565]	validation_0-auc:0.878543
# [566]	validation_0-auc:0.878631
# [567]	validation_0-auc:0.878649
# [568]	validation_0-auc:0.878688
# [569]	validation_0-auc:0.878765
# [570]	validation_0-auc:0.878807
# [571]	validation_0-auc:0.878867
# [572]	validation_0-auc:0.878936
# [573]	validation_0-auc:0.878957
# [574]	validation_0-auc:0.879033
# [575]	validation_0-auc:0.87908
# [576]	validation_0-auc:0.879089
# [577]	validation_0-auc:0.879107
# [578]	validation_0-auc:0.879111
# [579]	validation_0-auc:0.879201
# [580]	validation_0-auc:0.879231
# [581]	validation_0-auc:0.879238
# [582]	validation_0-auc:0.879268
# [583]	validation_0-auc:0.879329
# [584]	validation_0-auc:0.879359
# [585]	validation_0-auc:0.8794
# [586]	validation_0-auc:0.879456
# [587]	validation_0-auc:0.879477
# [588]	validation_0-auc:0.879549
# [589]	validation_0-auc:0.879604
# [590]	validation_0-auc:0.879611
# [591]	validation_0-auc:0.879626
# [592]	validation_0-auc:0.879664
# [593]	validation_0-auc:0.879739
# [594]	validation_0-auc:0.879755
# [595]	validation_0-auc:0.879804
# [596]	validation_0-auc:0.879825
# [597]	validation_0-auc:0.879877
# [598]	validation_0-auc:0.87989
# [599]	validation_0-auc:0.879896
# [600]	validation_0-auc:0.879921
# [601]	validation_0-auc:0.880004
# [602]	validation_0-auc:0.88007
# [603]	validation_0-auc:0.880096
# [604]	validation_0-auc:0.880099
# [605]	validation_0-auc:0.880197
# [606]	validation_0-auc:0.88022
# [607]	validation_0-auc:0.88025
# [608]	validation_0-auc:0.880303
# [609]	validation_0-auc:0.880334
# [610]	validation_0-auc:0.880501
# [611]	validation_0-auc:0.880521
# [612]	validation_0-auc:0.880542
# [613]	validation_0-auc:0.880562
# [614]	validation_0-auc:0.880604
# [615]	validation_0-auc:0.880621
# [616]	validation_0-auc:0.880684
# [617]	validation_0-auc:0.880739
# [618]	validation_0-auc:0.880812
# [619]	validation_0-auc:0.880827
# [620]	validation_0-auc:0.88084
# [621]	validation_0-auc:0.880886
# [622]	validation_0-auc:0.880883
# [623]	validation_0-auc:0.880938
# [624]	validation_0-auc:0.881025
# [625]	validation_0-auc:0.881033
# [626]	validation_0-auc:0.881051
# [627]	validation_0-auc:0.881061
# [628]	validation_0-auc:0.881151
# [629]	validation_0-auc:0.881173
# [630]	validation_0-auc:0.881176
# [631]	validation_0-auc:0.881197
# [632]	validation_0-auc:0.881207
# [633]	validation_0-auc:0.881248
# [634]	validation_0-auc:0.881253
# [635]	validation_0-auc:0.881294
# [636]	validation_0-auc:0.881328
# [637]	validation_0-auc:0.881358
# [638]	validation_0-auc:0.881511
# [639]	validation_0-auc:0.881599
# [640]	validation_0-auc:0.881642
# [641]	validation_0-auc:0.881719
# [642]	validation_0-auc:0.881722
# [643]	validation_0-auc:0.881737
# [644]	validation_0-auc:0.881775
# [645]	validation_0-auc:0.881845
# [646]	validation_0-auc:0.881861
# [647]	validation_0-auc:0.881856
# [648]	validation_0-auc:0.881873
# [649]	validation_0-auc:0.881945
# [650]	validation_0-auc:0.881963
# [651]	validation_0-auc:0.882012
# [652]	validation_0-auc:0.882065
# [653]	validation_0-auc:0.882137
# [654]	validation_0-auc:0.88217
# [655]	validation_0-auc:0.882211
# [656]	validation_0-auc:0.88227
# [657]	validation_0-auc:0.882302
# [658]	validation_0-auc:0.882331
# [659]	validation_0-auc:0.88236
# [660]	validation_0-auc:0.882428
# [661]	validation_0-auc:0.882482
# [662]	validation_0-auc:0.882494
# [663]	validation_0-auc:0.882523
# [664]	validation_0-auc:0.88259
# [665]	validation_0-auc:0.882591
# [666]	validation_0-auc:0.882634
# [667]	validation_0-auc:0.882676
# [668]	validation_0-auc:0.882684
# [669]	validation_0-auc:0.882708
# [670]	validation_0-auc:0.882743
# [671]	validation_0-auc:0.882759
# [672]	validation_0-auc:0.882818
# [673]	validation_0-auc:0.88282
# [674]	validation_0-auc:0.882884
# [675]	validation_0-auc:0.88299
# [676]	validation_0-auc:0.882998
# [677]	validation_0-auc:0.883069
# [678]	validation_0-auc:0.883096
# [679]	validation_0-auc:0.883134
# [680]	validation_0-auc:0.883181
# [681]	validation_0-auc:0.883198
# [682]	validation_0-auc:0.883241
# [683]	validation_0-auc:0.883297
# [684]	validation_0-auc:0.883318
# [685]	validation_0-auc:0.883338
# [686]	validation_0-auc:0.883418
# [687]	validation_0-auc:0.883439
# [688]	validation_0-auc:0.883471
# [689]	validation_0-auc:0.883519
# [690]	validation_0-auc:0.883552
# [691]	validation_0-auc:0.883597
# [692]	validation_0-auc:0.883653
# [693]	validation_0-auc:0.883683
# [694]	validation_0-auc:0.883749
# [695]	validation_0-auc:0.883818
# [696]	validation_0-auc:0.883866
# [697]	validation_0-auc:0.883882
# [698]	validation_0-auc:0.883905
# [699]	validation_0-auc:0.883932
# [700]	validation_0-auc:0.883959
# [701]	validation_0-auc:0.884032
# [702]	validation_0-auc:0.884054
# [703]	validation_0-auc:0.884082
# [704]	validation_0-auc:0.884134
# [705]	validation_0-auc:0.884193
# [706]	validation_0-auc:0.884216
# [707]	validation_0-auc:0.884225
# [708]	validation_0-auc:0.884252
# [709]	validation_0-auc:0.884295
# [710]	validation_0-auc:0.884332
# [711]	validation_0-auc:0.884379
# [712]	validation_0-auc:0.884381
# [713]	validation_0-auc:0.884495
# [714]	validation_0-auc:0.884508
# [715]	validation_0-auc:0.884561
# [716]	validation_0-auc:0.884607
# [717]	validation_0-auc:0.884615
# [718]	validation_0-auc:0.884646
# [719]	validation_0-auc:0.884681
# [720]	validation_0-auc:0.884701
# [721]	validation_0-auc:0.884725
# [722]	validation_0-auc:0.884763
# [723]	validation_0-auc:0.884773
# [724]	validation_0-auc:0.884903
# [725]	validation_0-auc:0.884932
# [726]	validation_0-auc:0.884949
# [727]	validation_0-auc:0.88497
# [728]	validation_0-auc:0.885034
# [729]	validation_0-auc:0.885131
# [730]	validation_0-auc:0.885204
# [731]	validation_0-auc:0.88523
# [732]	validation_0-auc:0.885278
# [733]	validation_0-auc:0.885293
# [734]	validation_0-auc:0.88532
# [735]	validation_0-auc:0.885404
# [736]	validation_0-auc:0.885423
# [737]	validation_0-auc:0.885519
# [738]	validation_0-auc:0.885543
# [739]	validation_0-auc:0.885554
# [740]	validation_0-auc:0.885586
# [741]	validation_0-auc:0.885639
# [742]	validation_0-auc:0.885716
# [743]	validation_0-auc:0.885767
# [744]	validation_0-auc:0.885801
# [745]	validation_0-auc:0.885824
# [746]	validation_0-auc:0.885908
# [747]	validation_0-auc:0.885942
# [748]	validation_0-auc:0.885963
# [749]	validation_0-auc:0.885964
# [0]	validation_0-auc:0.805068
# Will train until validation_0-auc hasn't improved in 20 rounds.
# [1]	validation_0-auc:0.812974
# [2]	validation_0-auc:0.81595
# [3]	validation_0-auc:0.817279
# [4]	validation_0-auc:0.821205
# [5]	validation_0-auc:0.822395
# [6]	validation_0-auc:0.820931
# [7]	validation_0-auc:0.821956
# [8]	validation_0-auc:0.824225
# [9]	validation_0-auc:0.823975
# [10]	validation_0-auc:0.82505
# [11]	validation_0-auc:0.826917
# [12]	validation_0-auc:0.827521
# [13]	validation_0-auc:0.827343
# [14]	validation_0-auc:0.827931
# [15]	validation_0-auc:0.82812
# [16]	validation_0-auc:0.829072
# [17]	validation_0-auc:0.830149
# [18]	validation_0-auc:0.83023
# [19]	validation_0-auc:0.830793
# [20]	validation_0-auc:0.830838
# [21]	validation_0-auc:0.830924
# [22]	validation_0-auc:0.831421
# [23]	validation_0-auc:0.831912
# [24]	validation_0-auc:0.831294
# [25]	validation_0-auc:0.832032
# [26]	validation_0-auc:0.832085
# [27]	validation_0-auc:0.83191
# [28]	validation_0-auc:0.83229
# [29]	validation_0-auc:0.831955
# [30]	validation_0-auc:0.832709
# [31]	validation_0-auc:0.833069
# [32]	validation_0-auc:0.833408
# [33]	validation_0-auc:0.833508
# [34]	validation_0-auc:0.833719
# [35]	validation_0-auc:0.834156
# [36]	validation_0-auc:0.834005
# [37]	validation_0-auc:0.83392
# [38]	validation_0-auc:0.833959
# [39]	validation_0-auc:0.83398
# [40]	validation_0-auc:0.833957
# [41]	validation_0-auc:0.833771
# [42]	validation_0-auc:0.834747
# [43]	validation_0-auc:0.83494
# [44]	validation_0-auc:0.835167
# [45]	validation_0-auc:0.835299
# [46]	validation_0-auc:0.835245
# [47]	validation_0-auc:0.835693
# [48]	validation_0-auc:0.835938
# [49]	validation_0-auc:0.835973
# [50]	validation_0-auc:0.836086
# [51]	validation_0-auc:0.835839
# [52]	validation_0-auc:0.836267
# [53]	validation_0-auc:0.836625
# [54]	validation_0-auc:0.836557
# [55]	validation_0-auc:0.836949
# [56]	validation_0-auc:0.837146
# [57]	validation_0-auc:0.837293
# [58]	validation_0-auc:0.837371
# [59]	validation_0-auc:0.837521
# [60]	validation_0-auc:0.837458
# [61]	validation_0-auc:0.8379
# [62]	validation_0-auc:0.837975
# [63]	validation_0-auc:0.838309
# [64]	validation_0-auc:0.838677
# [65]	validation_0-auc:0.838959
# [66]	validation_0-auc:0.83907
# [67]	validation_0-auc:0.839103
# [68]	validation_0-auc:0.839146
# [69]	validation_0-auc:0.84036
# [70]	validation_0-auc:0.840267
# [71]	validation_0-auc:0.840451
# [72]	validation_0-auc:0.840656
# [73]	validation_0-auc:0.840709
# [74]	validation_0-auc:0.840895
# [75]	validation_0-auc:0.840802
# [76]	validation_0-auc:0.841063
# [77]	validation_0-auc:0.841052
# [78]	validation_0-auc:0.841033
# [79]	validation_0-auc:0.840979
# [80]	validation_0-auc:0.841413
# [81]	validation_0-auc:0.841354
# [82]	validation_0-auc:0.841497
# [83]	validation_0-auc:0.841559
# [84]	validation_0-auc:0.841692
# [85]	validation_0-auc:0.84153
# [86]	validation_0-auc:0.841877
# [87]	validation_0-auc:0.841786
# [88]	validation_0-auc:0.841792
# [89]	validation_0-auc:0.841926
# [90]	validation_0-auc:0.841886
# [91]	validation_0-auc:0.842113
# [92]	validation_0-auc:0.842262
# [93]	validation_0-auc:0.842289
# [94]	validation_0-auc:0.842513
# [95]	validation_0-auc:0.842555
# [96]	validation_0-auc:0.842693
# [97]	validation_0-auc:0.842932
# [98]	validation_0-auc:0.842964
# [99]	validation_0-auc:0.843043
# [100]	validation_0-auc:0.843228
# [101]	validation_0-auc:0.843458
# [102]	validation_0-auc:0.843625
# [103]	validation_0-auc:0.843761
# [104]	validation_0-auc:0.84383
# [105]	validation_0-auc:0.844046
# [106]	validation_0-auc:0.844061
# [107]	validation_0-auc:0.844201
# [108]	validation_0-auc:0.844225
# [109]	validation_0-auc:0.844312
# [110]	validation_0-auc:0.844493
# [111]	validation_0-auc:0.844652
# [112]	validation_0-auc:0.84477
# [113]	validation_0-auc:0.844867
# [114]	validation_0-auc:0.844925
# [115]	validation_0-auc:0.844987
# [116]	validation_0-auc:0.845326
# [117]	validation_0-auc:0.84534
# [118]	validation_0-auc:0.845498
# [119]	validation_0-auc:0.845677
# [120]	validation_0-auc:0.845901
# [121]	validation_0-auc:0.846188
# [122]	validation_0-auc:0.846318
# [123]	validation_0-auc:0.846473
# [124]	validation_0-auc:0.846522
# [125]	validation_0-auc:0.846752
# [126]	validation_0-auc:0.847042
# [127]	validation_0-auc:0.847147
# [128]	validation_0-auc:0.847267
# [129]	validation_0-auc:0.847397
# [130]	validation_0-auc:0.847517
# [131]	validation_0-auc:0.847633
# [132]	validation_0-auc:0.84779
# [133]	validation_0-auc:0.848021
# [134]	validation_0-auc:0.848091
# [135]	validation_0-auc:0.848126
# [136]	validation_0-auc:0.848368
# [137]	validation_0-auc:0.84831
# [138]	validation_0-auc:0.848395
# [139]	validation_0-auc:0.848459
# [140]	validation_0-auc:0.848627
# [141]	validation_0-auc:0.848785
# [142]	validation_0-auc:0.848794
# [143]	validation_0-auc:0.848947
# [144]	validation_0-auc:0.849029
# [145]	validation_0-auc:0.849165
# [146]	validation_0-auc:0.849181
# [147]	validation_0-auc:0.849384
# [148]	validation_0-auc:0.849517
# [149]	validation_0-auc:0.84972
# [150]	validation_0-auc:0.849735
# [151]	validation_0-auc:0.849869
# [152]	validation_0-auc:0.850054
# [153]	validation_0-auc:0.850239
# [154]	validation_0-auc:0.850293
# [155]	validation_0-auc:0.850383
# [156]	validation_0-auc:0.850532
# [157]	validation_0-auc:0.850709
# [158]	validation_0-auc:0.850976
# [159]	validation_0-auc:0.851147
# [160]	validation_0-auc:0.851349
# [161]	validation_0-auc:0.851415
# [162]	validation_0-auc:0.851451
# [163]	validation_0-auc:0.851464
# [164]	validation_0-auc:0.851522
# [165]	validation_0-auc:0.851587
# [166]	validation_0-auc:0.851722
# [167]	validation_0-auc:0.8518
# [168]	validation_0-auc:0.851977
# [169]	validation_0-auc:0.852055
# [170]	validation_0-auc:0.852135
# [171]	validation_0-auc:0.852425
# [172]	validation_0-auc:0.852642
# [173]	validation_0-auc:0.852777
# [174]	validation_0-auc:0.852956
# [175]	validation_0-auc:0.853063
# [176]	validation_0-auc:0.853157
# [177]	validation_0-auc:0.85323
# [178]	validation_0-auc:0.853511
# [179]	validation_0-auc:0.853611
# [180]	validation_0-auc:0.853699
# [181]	validation_0-auc:0.853838
# [182]	validation_0-auc:0.853963
# [183]	validation_0-auc:0.854025
# [184]	validation_0-auc:0.854212
# [185]	validation_0-auc:0.85429
# [186]	validation_0-auc:0.854366
# [187]	validation_0-auc:0.854567
# [188]	validation_0-auc:0.854669
# [189]	validation_0-auc:0.854749
# [190]	validation_0-auc:0.854891
# [191]	validation_0-auc:0.854955
# [192]	validation_0-auc:0.855158
# [193]	validation_0-auc:0.85524
# [194]	validation_0-auc:0.855243
# [195]	validation_0-auc:0.855509
# [196]	validation_0-auc:0.855624
# [197]	validation_0-auc:0.855755
# [198]	validation_0-auc:0.855878
# [199]	validation_0-auc:0.855965
# [200]	validation_0-auc:0.856083
# [201]	validation_0-auc:0.856196
# [202]	validation_0-auc:0.856283
# [203]	validation_0-auc:0.856401
# [204]	validation_0-auc:0.856452
# [205]	validation_0-auc:0.856564
# [206]	validation_0-auc:0.856683
# [207]	validation_0-auc:0.85674
# [208]	validation_0-auc:0.856781
# [209]	validation_0-auc:0.856856
# [210]	validation_0-auc:0.856948
# [211]	validation_0-auc:0.857077
# [212]	validation_0-auc:0.857211
# [213]	validation_0-auc:0.857276
# [214]	validation_0-auc:0.857341
# [215]	validation_0-auc:0.857445
# [216]	validation_0-auc:0.857626
# [217]	validation_0-auc:0.857816
# [218]	validation_0-auc:0.857957
# [219]	validation_0-auc:0.858005
# [220]	validation_0-auc:0.858032
# [221]	validation_0-auc:0.858166
# [222]	validation_0-auc:0.858326
# [223]	validation_0-auc:0.858397
# [224]	validation_0-auc:0.858551
# [225]	validation_0-auc:0.858528
# [226]	validation_0-auc:0.858638
# [227]	validation_0-auc:0.858719
# [228]	validation_0-auc:0.858844
# [229]	validation_0-auc:0.859
# [230]	validation_0-auc:0.859072
# [231]	validation_0-auc:0.859275
# [232]	validation_0-auc:0.859446
# [233]	validation_0-auc:0.859551
# [234]	validation_0-auc:0.859633
# [235]	validation_0-auc:0.859684
# [236]	validation_0-auc:0.859702
# [237]	validation_0-auc:0.859788
# [238]	validation_0-auc:0.859865
# [239]	validation_0-auc:0.859991
# [240]	validation_0-auc:0.860018
# [241]	validation_0-auc:0.860059
# [242]	validation_0-auc:0.860109
# [243]	validation_0-auc:0.86028
# [244]	validation_0-auc:0.860401
# [245]	validation_0-auc:0.86043
# [246]	validation_0-auc:0.860532
# [247]	validation_0-auc:0.860599
# [248]	validation_0-auc:0.860646
# [249]	validation_0-auc:0.860736
# [250]	validation_0-auc:0.860833
# [251]	validation_0-auc:0.860886
# [252]	validation_0-auc:0.860908
# [253]	validation_0-auc:0.860982
# [254]	validation_0-auc:0.861023
# [255]	validation_0-auc:0.861258
# [256]	validation_0-auc:0.861281
# [257]	validation_0-auc:0.861322
# [258]	validation_0-auc:0.861358
# [259]	validation_0-auc:0.861324
# [260]	validation_0-auc:0.861379
# [261]	validation_0-auc:0.861435
# [262]	validation_0-auc:0.861499
# [263]	validation_0-auc:0.861602
# [264]	validation_0-auc:0.861669
# [265]	validation_0-auc:0.861821
# [266]	validation_0-auc:0.86189
# [267]	validation_0-auc:0.862005
# [268]	validation_0-auc:0.862162
# [269]	validation_0-auc:0.862319
# [270]	validation_0-auc:0.862361
# [271]	validation_0-auc:0.862418
# [272]	validation_0-auc:0.862452
# [273]	validation_0-auc:0.862551
# [274]	validation_0-auc:0.86261
# [275]	validation_0-auc:0.862694
# [276]	validation_0-auc:0.862777
# [277]	validation_0-auc:0.862844
# [278]	validation_0-auc:0.86292
# [279]	validation_0-auc:0.86305
# [280]	validation_0-auc:0.863166
# [281]	validation_0-auc:0.863241
# [282]	validation_0-auc:0.863328
# [283]	validation_0-auc:0.863426
# [284]	validation_0-auc:0.863548
# [285]	validation_0-auc:0.8636
# [286]	validation_0-auc:0.863644
# [287]	validation_0-auc:0.863708
# [288]	validation_0-auc:0.863771
# [289]	validation_0-auc:0.863816
# [290]	validation_0-auc:0.863878
# [291]	validation_0-auc:0.864046
# [292]	validation_0-auc:0.864036
# [293]	validation_0-auc:0.864088
# [294]	validation_0-auc:0.864202
# [295]	validation_0-auc:0.86429
# [296]	validation_0-auc:0.864451
# [297]	validation_0-auc:0.864539
# [298]	validation_0-auc:0.86462
# [299]	validation_0-auc:0.86463
# [300]	validation_0-auc:0.864639
# [301]	validation_0-auc:0.864725
# [302]	validation_0-auc:0.864762
# [303]	validation_0-auc:0.864817
# [304]	validation_0-auc:0.864865
# [305]	validation_0-auc:0.864914
# [306]	validation_0-auc:0.864948
# [307]	validation_0-auc:0.864993
# [308]	validation_0-auc:0.865066
# [309]	validation_0-auc:0.865178
# [310]	validation_0-auc:0.865319
# [311]	validation_0-auc:0.865316
# [312]	validation_0-auc:0.865402
# [313]	validation_0-auc:0.865404
# [314]	validation_0-auc:0.865475
# [315]	validation_0-auc:0.865621
# [316]	validation_0-auc:0.865675
# [317]	validation_0-auc:0.865707
# [318]	validation_0-auc:0.865742
# [319]	validation_0-auc:0.865769
# [320]	validation_0-auc:0.865857
# [321]	validation_0-auc:0.865879
# [322]	validation_0-auc:0.86594
# [323]	validation_0-auc:0.866018
# [324]	validation_0-auc:0.86615
# [325]	validation_0-auc:0.866251
# [326]	validation_0-auc:0.866372
# [327]	validation_0-auc:0.866397
# [328]	validation_0-auc:0.866493
# [329]	validation_0-auc:0.866552
# [330]	validation_0-auc:0.866602
# [331]	validation_0-auc:0.866639
# [332]	validation_0-auc:0.866702
# [333]	validation_0-auc:0.866763
# [334]	validation_0-auc:0.866766
# [335]	validation_0-auc:0.866828
# [336]	validation_0-auc:0.86688
# [337]	validation_0-auc:0.866953
# [338]	validation_0-auc:0.867014
# [339]	validation_0-auc:0.867072
# [340]	validation_0-auc:0.86712
# [341]	validation_0-auc:0.867145
# [342]	validation_0-auc:0.867182
# [343]	validation_0-auc:0.867259
# [344]	validation_0-auc:0.867398
# [345]	validation_0-auc:0.867406
# [346]	validation_0-auc:0.867491
# [347]	validation_0-auc:0.867533
# [348]	validation_0-auc:0.867546
# [349]	validation_0-auc:0.867604
# [350]	validation_0-auc:0.867625
# [351]	validation_0-auc:0.867657
# [352]	validation_0-auc:0.867692
# [353]	validation_0-auc:0.867701
# [354]	validation_0-auc:0.867734
# [355]	validation_0-auc:0.867735
# [356]	validation_0-auc:0.867796
# [357]	validation_0-auc:0.867887
# [358]	validation_0-auc:0.867946
# [359]	validation_0-auc:0.867998
# [360]	validation_0-auc:0.867994
# [361]	validation_0-auc:0.86803
# [362]	validation_0-auc:0.868086
# [363]	validation_0-auc:0.868145
# [364]	validation_0-auc:0.868178
# [365]	validation_0-auc:0.868241
# [366]	validation_0-auc:0.868273
# [367]	validation_0-auc:0.868326
# [368]	validation_0-auc:0.868344
# [369]	validation_0-auc:0.86838
# [370]	validation_0-auc:0.86844
# [371]	validation_0-auc:0.86847
# [372]	validation_0-auc:0.868482
# [373]	validation_0-auc:0.868475
# [374]	validation_0-auc:0.868532
# [375]	validation_0-auc:0.868643
# [376]	validation_0-auc:0.86864
# [377]	validation_0-auc:0.868693
# [378]	validation_0-auc:0.868733
# [379]	validation_0-auc:0.868758
# [380]	validation_0-auc:0.86883
# [381]	validation_0-auc:0.868854
# [382]	validation_0-auc:0.868878
# [383]	validation_0-auc:0.868902
# [384]	validation_0-auc:0.868897
# [385]	validation_0-auc:0.868923
# [386]	validation_0-auc:0.869002
# [387]	validation_0-auc:0.869104
# [388]	validation_0-auc:0.869156
# [389]	validation_0-auc:0.86918
# [390]	validation_0-auc:0.869336
# [391]	validation_0-auc:0.869361
# [392]	validation_0-auc:0.869448
# [393]	validation_0-auc:0.869489
# [394]	validation_0-auc:0.869552
# [395]	validation_0-auc:0.869599
# [396]	validation_0-auc:0.869632
# [397]	validation_0-auc:0.869663
# [398]	validation_0-auc:0.869694
# [399]	validation_0-auc:0.869729
# [400]	validation_0-auc:0.869817
# [401]	validation_0-auc:0.869867
# [402]	validation_0-auc:0.869953
# [403]	validation_0-auc:0.869983
# [404]	validation_0-auc:0.870054
# [405]	validation_0-auc:0.87012
# [406]	validation_0-auc:0.870211
# [407]	validation_0-auc:0.870254
# [408]	validation_0-auc:0.870321
# [409]	validation_0-auc:0.870384
# [410]	validation_0-auc:0.870405
# [411]	validation_0-auc:0.870428
# [412]	validation_0-auc:0.870486
# [413]	validation_0-auc:0.870548
# [414]	validation_0-auc:0.87058
# [415]	validation_0-auc:0.870601
# [416]	validation_0-auc:0.870635
# [417]	validation_0-auc:0.870686
# [418]	validation_0-auc:0.870727
# [419]	validation_0-auc:0.870768
# [420]	validation_0-auc:0.870802
# [421]	validation_0-auc:0.870941
# [422]	validation_0-auc:0.871007
# [423]	validation_0-auc:0.871121
# [424]	validation_0-auc:0.871152
# [425]	validation_0-auc:0.871144
# [426]	validation_0-auc:0.871165
# [427]	validation_0-auc:0.871256
# [428]	validation_0-auc:0.871284
# [429]	validation_0-auc:0.871304
# [430]	validation_0-auc:0.871334
# [431]	validation_0-auc:0.871335
# [432]	validation_0-auc:0.871329
# [433]	validation_0-auc:0.871357
# [434]	validation_0-auc:0.871395
# [435]	validation_0-auc:0.87144
# [436]	validation_0-auc:0.87157
# [437]	validation_0-auc:0.871641
# [438]	validation_0-auc:0.871737
# [439]	validation_0-auc:0.871783
# [440]	validation_0-auc:0.871806
# [441]	validation_0-auc:0.87191
# [442]	validation_0-auc:0.872001
# [443]	validation_0-auc:0.872024
# [444]	validation_0-auc:0.87208
# [445]	validation_0-auc:0.872128
# [446]	validation_0-auc:0.87218
# [447]	validation_0-auc:0.872205
# [448]	validation_0-auc:0.872344
# [449]	validation_0-auc:0.872382
# [450]	validation_0-auc:0.872391
# [451]	validation_0-auc:0.872412
# [452]	validation_0-auc:0.872503
# [453]	validation_0-auc:0.87256
# [454]	validation_0-auc:0.872585
# [455]	validation_0-auc:0.87261
# [456]	validation_0-auc:0.872664
# [457]	validation_0-auc:0.872705
# [458]	validation_0-auc:0.872722
# [459]	validation_0-auc:0.872734
# [460]	validation_0-auc:0.87275
# [461]	validation_0-auc:0.872801
# [462]	validation_0-auc:0.872883
# [463]	validation_0-auc:0.872987
# [464]	validation_0-auc:0.873055
# [465]	validation_0-auc:0.8731
# [466]	validation_0-auc:0.873145
# [467]	validation_0-auc:0.873186
# [468]	validation_0-auc:0.873294
# [469]	validation_0-auc:0.87335
# [470]	validation_0-auc:0.873392
# [471]	validation_0-auc:0.873471
# [472]	validation_0-auc:0.873521
# [473]	validation_0-auc:0.873549
# [474]	validation_0-auc:0.873621
# [475]	validation_0-auc:0.873638
# [476]	validation_0-auc:0.873671
# [477]	validation_0-auc:0.873745
# [478]	validation_0-auc:0.873741
# [479]	validation_0-auc:0.87382
# [480]	validation_0-auc:0.873811
# [481]	validation_0-auc:0.873822
# [482]	validation_0-auc:0.873829
# [483]	validation_0-auc:0.873842
# [484]	validation_0-auc:0.873937
# [485]	validation_0-auc:0.87398
# [486]	validation_0-auc:0.873966
# [487]	validation_0-auc:0.873991
# [488]	validation_0-auc:0.874009
# [489]	validation_0-auc:0.874079
# [490]	validation_0-auc:0.874147
# [491]	validation_0-auc:0.874224
# [492]	validation_0-auc:0.874325
# [493]	validation_0-auc:0.87435
# [494]	validation_0-auc:0.874382
# [495]	validation_0-auc:0.874413
# [496]	validation_0-auc:0.874577
# [497]	validation_0-auc:0.874603
# [498]	validation_0-auc:0.874703
# [499]	validation_0-auc:0.87477
# [500]	validation_0-auc:0.874772
# [501]	validation_0-auc:0.874848
# [502]	validation_0-auc:0.874884
# [503]	validation_0-auc:0.874915
# [504]	validation_0-auc:0.874981
# [505]	validation_0-auc:0.875055
# [506]	validation_0-auc:0.875137
# [507]	validation_0-auc:0.875151
# [508]	validation_0-auc:0.875187
# [509]	validation_0-auc:0.875255
# [510]	validation_0-auc:0.875332
# [511]	validation_0-auc:0.875368
# [512]	validation_0-auc:0.875401
# [513]	validation_0-auc:0.875446
# [514]	validation_0-auc:0.875471
# [515]	validation_0-auc:0.875488
# [516]	validation_0-auc:0.875598
# [517]	validation_0-auc:0.875653
# [518]	validation_0-auc:0.875701
# [519]	validation_0-auc:0.875703
# [520]	validation_0-auc:0.875728
# [521]	validation_0-auc:0.875758
# [522]	validation_0-auc:0.875887
# [523]	validation_0-auc:0.876029
# [524]	validation_0-auc:0.876062
# [525]	validation_0-auc:0.876185
# [526]	validation_0-auc:0.876261
# [527]	validation_0-auc:0.876324
# [528]	validation_0-auc:0.876365
# [529]	validation_0-auc:0.87646
# [530]	validation_0-auc:0.876494
# [531]	validation_0-auc:0.87649
# [532]	validation_0-auc:0.876498
# [533]	validation_0-auc:0.876549
# [534]	validation_0-auc:0.876538
# [535]	validation_0-auc:0.87657
# [536]	validation_0-auc:0.876621
# [537]	validation_0-auc:0.876616
# [538]	validation_0-auc:0.876696
# [539]	validation_0-auc:0.876745
# [540]	validation_0-auc:0.876787
# [541]	validation_0-auc:0.876826
# [542]	validation_0-auc:0.876973
# [543]	validation_0-auc:0.877066
# [544]	validation_0-auc:0.877109
# [545]	validation_0-auc:0.877172
# [546]	validation_0-auc:0.877194
# [547]	validation_0-auc:0.877209
# [548]	validation_0-auc:0.877237
# [549]	validation_0-auc:0.877288
# [550]	validation_0-auc:0.877412
# [551]	validation_0-auc:0.877479
# [552]	validation_0-auc:0.877532
# [553]	validation_0-auc:0.877626
# [554]	validation_0-auc:0.877709
# [555]	validation_0-auc:0.877739
# [556]	validation_0-auc:0.87775
# [557]	validation_0-auc:0.877804
# [558]	validation_0-auc:0.877841
# [559]	validation_0-auc:0.877879
# [560]	validation_0-auc:0.877981
# [561]	validation_0-auc:0.878053
# [562]	validation_0-auc:0.878143
# [563]	validation_0-auc:0.878172
# [564]	validation_0-auc:0.878201
# [565]	validation_0-auc:0.87821
# [566]	validation_0-auc:0.878232
# [567]	validation_0-auc:0.87829
# [568]	validation_0-auc:0.878308
# [569]	validation_0-auc:0.878365
# [570]	validation_0-auc:0.878378
# [571]	validation_0-auc:0.878427
# [572]	validation_0-auc:0.878462
# [573]	validation_0-auc:0.878488
# [574]	validation_0-auc:0.878519
# [575]	validation_0-auc:0.878534
# [576]	validation_0-auc:0.878556
# [577]	validation_0-auc:0.878608
# [578]	validation_0-auc:0.878645
# [579]	validation_0-auc:0.878672
# [580]	validation_0-auc:0.878678
# [581]	validation_0-auc:0.878738
# [582]	validation_0-auc:0.878825
# [583]	validation_0-auc:0.878924
# [584]	validation_0-auc:0.87897
# [585]	validation_0-auc:0.878999
# [586]	validation_0-auc:0.879074
# [587]	validation_0-auc:0.879146
# [588]	validation_0-auc:0.879186
# [589]	validation_0-auc:0.87923
# [590]	validation_0-auc:0.879259
# [591]	validation_0-auc:0.879293
# [592]	validation_0-auc:0.879362
# [593]	validation_0-auc:0.879429
# [594]	validation_0-auc:0.87948
# [595]	validation_0-auc:0.879525
# [596]	validation_0-auc:0.879574
# [597]	validation_0-auc:0.879609
# [598]	validation_0-auc:0.879652
# [599]	validation_0-auc:0.879668
# [600]	validation_0-auc:0.879795
# [601]	validation_0-auc:0.879811
# [602]	validation_0-auc:0.879841
# [603]	validation_0-auc:0.879893
# [604]	validation_0-auc:0.879966
# [605]	validation_0-auc:0.879964
# [606]	validation_0-auc:0.880036
# [607]	validation_0-auc:0.8801
# [608]	validation_0-auc:0.880091
# [609]	validation_0-auc:0.880124
# [610]	validation_0-auc:0.880113
# [611]	validation_0-auc:0.880134
# [612]	validation_0-auc:0.880149
# [613]	validation_0-auc:0.880168
# [614]	validation_0-auc:0.880212
# [615]	validation_0-auc:0.880287
# [616]	validation_0-auc:0.880364
# [617]	validation_0-auc:0.880413
# [618]	validation_0-auc:0.880431
# [619]	validation_0-auc:0.880459
# [620]	validation_0-auc:0.880492
# [621]	validation_0-auc:0.880561
# [622]	validation_0-auc:0.880597
# [623]	validation_0-auc:0.880637
# [624]	validation_0-auc:0.880715
# [625]	validation_0-auc:0.880741
# [626]	validation_0-auc:0.880809
# [627]	validation_0-auc:0.880863
# [628]	validation_0-auc:0.8809
# [629]	validation_0-auc:0.880919
# [630]	validation_0-auc:0.880951
# [631]	validation_0-auc:0.880965
# [632]	validation_0-auc:0.880978
# [633]	validation_0-auc:0.881005
# [634]	validation_0-auc:0.88107
# [635]	validation_0-auc:0.881074
# [636]	validation_0-auc:0.881107
# [637]	validation_0-auc:0.881138
# [638]	validation_0-auc:0.881166
# [639]	validation_0-auc:0.881217
# [640]	validation_0-auc:0.881238
# [641]	validation_0-auc:0.881308
# [642]	validation_0-auc:0.88137
# [643]	validation_0-auc:0.881412
# [644]	validation_0-auc:0.881432
# [645]	validation_0-auc:0.881515
# [646]	validation_0-auc:0.881559
# [647]	validation_0-auc:0.881621
# [648]	validation_0-auc:0.881664
# [649]	validation_0-auc:0.881765
# [650]	validation_0-auc:0.881819
# [651]	validation_0-auc:0.881907
# [652]	validation_0-auc:0.881941
# [653]	validation_0-auc:0.881997
# [654]	validation_0-auc:0.882075
# [655]	validation_0-auc:0.882092
# [656]	validation_0-auc:0.88212
# [657]	validation_0-auc:0.882101
# [658]	validation_0-auc:0.882197
# [659]	validation_0-auc:0.882233
# [660]	validation_0-auc:0.882333
# [661]	validation_0-auc:0.882341
# [662]	validation_0-auc:0.882353
# [663]	validation_0-auc:0.882412
# [664]	validation_0-auc:0.882485
# [665]	validation_0-auc:0.882586
# [666]	validation_0-auc:0.882648
# [667]	validation_0-auc:0.882711
# [668]	validation_0-auc:0.882747
# [669]	validation_0-auc:0.882783
# [670]	validation_0-auc:0.882842
# [671]	validation_0-auc:0.882894
# [672]	validation_0-auc:0.882957
# [673]	validation_0-auc:0.883006
# [674]	validation_0-auc:0.883007
# [675]	validation_0-auc:0.883049
# [676]	validation_0-auc:0.883084
# [677]	validation_0-auc:0.883082
# [678]	validation_0-auc:0.883164
# [679]	validation_0-auc:0.883168
# [680]	validation_0-auc:0.883161
# [681]	validation_0-auc:0.883209
# [682]	validation_0-auc:0.883237
# [683]	validation_0-auc:0.883284
# [684]	validation_0-auc:0.883301
# [685]	validation_0-auc:0.883348
# [686]	validation_0-auc:0.883406
# [687]	validation_0-auc:0.883449
# [688]	validation_0-auc:0.883484
# [689]	validation_0-auc:0.883537
# [690]	validation_0-auc:0.883547
# [691]	validation_0-auc:0.883569
# [692]	validation_0-auc:0.883588
# [693]	validation_0-auc:0.883621
# [694]	validation_0-auc:0.883727
# [695]	validation_0-auc:0.883745
# [696]	validation_0-auc:0.88377
# [697]	validation_0-auc:0.883821
# [698]	validation_0-auc:0.883899
# [699]	validation_0-auc:0.883924
# [700]	validation_0-auc:0.883956
# [701]	validation_0-auc:0.884003
# [702]	validation_0-auc:0.884063
# [703]	validation_0-auc:0.884068
# [704]	validation_0-auc:0.884111
# [705]	validation_0-auc:0.884264
# [706]	validation_0-auc:0.88432
# [707]	validation_0-auc:0.884362
# [708]	validation_0-auc:0.884411
# [709]	validation_0-auc:0.88446
# [710]	validation_0-auc:0.884484
# [711]	validation_0-auc:0.884544
# [712]	validation_0-auc:0.88461
# [713]	validation_0-auc:0.884629
# [714]	validation_0-auc:0.884693
# [715]	validation_0-auc:0.884778
# [716]	validation_0-auc:0.884825
# [717]	validation_0-auc:0.884866
# [718]	validation_0-auc:0.884909
# [719]	validation_0-auc:0.884929
# [720]	validation_0-auc:0.88497
# [721]	validation_0-auc:0.884956
# [722]	validation_0-auc:0.884989
# [723]	validation_0-auc:0.885021
# [724]	validation_0-auc:0.885051
# [725]	validation_0-auc:0.885088
# [726]	validation_0-auc:0.885123
# [727]	validation_0-auc:0.885168
# [728]	validation_0-auc:0.885259
# [729]	validation_0-auc:0.885305
# [730]	validation_0-auc:0.88534
# [731]	validation_0-auc:0.885335
# [732]	validation_0-auc:0.88535
# [733]	validation_0-auc:0.88536
# [734]	validation_0-auc:0.885399
# [735]	validation_0-auc:0.885421
# [736]	validation_0-auc:0.885442
# [737]	validation_0-auc:0.885484
# [738]	validation_0-auc:0.88556
# [739]	validation_0-auc:0.885632
# [740]	validation_0-auc:0.885703
# [741]	validation_0-auc:0.885755
# [742]	validation_0-auc:0.885847
# [743]	validation_0-auc:0.885925
# [744]	validation_0-auc:0.886017
# [745]	validation_0-auc:0.886102
# [746]	validation_0-auc:0.886193
# [747]	validation_0-auc:0.886233
# [748]	validation_0-auc:0.886246
# [749]	validation_0-auc:0.886263
# [0]	validation_0-auc:0.803688
# Will train until validation_0-auc hasn't improved in 20 rounds.
# [1]	validation_0-auc:0.814362
# [2]	validation_0-auc:0.814124
# [3]	validation_0-auc:0.817381
# [4]	validation_0-auc:0.815476
# [5]	validation_0-auc:0.816213
# ...
# [249]	validation_0-auc:0.860714
# [250]	validation_0-auc:0.860805
# [251]	validation_0-auc:0.86087
# [252]	validation_0-auc:0.861062
# [253]	validation_0-auc:0.861032
# [254]	validation_0-auc:0.861207
# [255]	validation_0-auc:0.861248
# [256]	validation_0-auc:0.861391
# [257]	validation_0-auc:0.861378
# [258]	validation_0-auc:0.861464
# [259]	validation_0-auc:0.861558
# [260]	validation_0-auc:0.861553
# [261]	validation_0-auc:0.861643
# [262]	validation_0-auc:0.86189
# [263]	validation_0-auc:0.861938
# [264]	validation_0-auc:0.862023
# [265]	validation_0-auc:0.862054
# [266]	validation_0-auc:0.862148
# [267]	validation_0-auc:0.862205
# [268]	validation_0-auc:0.862272
# [269]	validation_0-auc:0.862363
# [270]	validation_0-auc:0.86243
# [271]	validation_0-auc:0.862515
# [272]	validation_0-auc:0.862618
# [273]	validation_0-auc:0.862709
# [274]	validation_0-auc:0.862802
# [275]	validation_0-auc:0.863013
# [276]	validation_0-auc:0.863093
# [277]	validation_0-auc:0.863121
# [278]	validation_0-auc:0.863247
# [279]	validation_0-auc:0.863427
# [280]	validation_0-auc:0.863518
# [281]	validation_0-auc:0.863657
# [282]	validation_0-auc:0.863709
# [283]	validation_0-auc:0.863823
# [284]	validation_0-auc:0.863887
# [285]	validation_0-auc:0.863944
# [286]	validation_0-auc:0.864016
# [287]	validation_0-auc:0.864075
# [288]	validation_0-auc:0.864227
# [289]	validation_0-auc:0.864251
# [290]	validation_0-auc:0.864307
# [291]	validation_0-auc:0.864357
# [292]	validation_0-auc:0.864407
# [293]	validation_0-auc:0.864445
# [294]	validation_0-auc:0.86448
# [295]	validation_0-auc:0.864499
# [296]	validation_0-auc:0.864545
# [297]	validation_0-auc:0.864576
# [298]	validation_0-auc:0.864603
# [299]	validation_0-auc:0.86465
# [300]	validation_0-auc:0.86465
# [301]	validation_0-auc:0.8647
# [302]	validation_0-auc:0.864727
# [303]	validation_0-auc:0.86477
# [304]	validation_0-auc:0.864777
# [305]	validation_0-auc:0.864813
# [306]	validation_0-auc:0.864891
# [307]	validation_0-auc:0.864936
# [308]	validation_0-auc:0.865113
# [309]	validation_0-auc:0.865124
# [310]	validation_0-auc:0.865159
# [311]	validation_0-auc:0.865216
# [312]	validation_0-auc:0.865258
# [313]	validation_0-auc:0.865312
# [314]	validation_0-auc:0.865337
# [315]	validation_0-auc:0.865399
# [316]	validation_0-auc:0.865427
# [317]	validation_0-auc:0.865479
# [318]	validation_0-auc:0.865578
# [319]	validation_0-auc:0.865627
# [320]	validation_0-auc:0.86567
# [321]	validation_0-auc:0.8657
# [322]	validation_0-auc:0.865765
# [323]	validation_0-auc:0.865799
# [324]	validation_0-auc:0.865862
# [325]	validation_0-auc:0.865906
# [326]	validation_0-auc:0.865917
# [327]	validation_0-auc:0.86603
# [328]	validation_0-auc:0.866085
# [329]	validation_0-auc:0.866168
# [330]	validation_0-auc:0.866219
# [331]	validation_0-auc:0.866265
# [332]	validation_0-auc:0.866324
# [333]	validation_0-auc:0.866338
# [334]	validation_0-auc:0.866503
# [335]	validation_0-auc:0.866521
# [336]	validation_0-auc:0.86667
# [337]	validation_0-auc:0.866713
# [338]	validation_0-auc:0.866776
# [339]	validation_0-auc:0.866859
# [340]	validation_0-auc:0.866952
# [341]	validation_0-auc:0.867001
# [342]	validation_0-auc:0.867031
# [343]	validation_0-auc:0.867046
# [344]	validation_0-auc:0.867112
# [345]	validation_0-auc:0.867198
# [346]	validation_0-auc:0.867229
# [347]	validation_0-auc:0.867266
# [348]	validation_0-auc:0.867346
# [349]	validation_0-auc:0.867375
# [350]	validation_0-auc:0.86752
# [351]	validation_0-auc:0.867586
# [352]	validation_0-auc:0.86761
# [353]	validation_0-auc:0.867609
# [354]	validation_0-auc:0.867587
# [355]	validation_0-auc:0.867621
# [356]	validation_0-auc:0.867725
# [357]	validation_0-auc:0.867753
# [358]	validation_0-auc:0.867756
# [359]	validation_0-auc:0.867867
# [360]	validation_0-auc:0.867975
# [361]	validation_0-auc:0.868061
# [362]	validation_0-auc:0.86816
# [363]	validation_0-auc:0.868189
# [364]	validation_0-auc:0.868282
# [365]	validation_0-auc:0.868351
# [366]	validation_0-auc:0.868424
# [367]	validation_0-auc:0.868468
# [368]	validation_0-auc:0.868522
# [369]	validation_0-auc:0.868749
# [370]	validation_0-auc:0.868761
# [371]	validation_0-auc:0.868832
# [372]	validation_0-auc:0.868908
# [373]	validation_0-auc:0.868967
# [374]	validation_0-auc:0.869002
# [375]	validation_0-auc:0.869043
# [376]	validation_0-auc:0.869147
# [377]	validation_0-auc:0.869179
# [378]	validation_0-auc:0.869242
# [379]	validation_0-auc:0.869296
# [380]	validation_0-auc:0.869414
# [381]	validation_0-auc:0.869481
# [382]	validation_0-auc:0.869522
# [383]	validation_0-auc:0.869549
# [384]	validation_0-auc:0.869603
# [385]	validation_0-auc:0.869626
# [386]	validation_0-auc:0.869664
# [387]	validation_0-auc:0.869749
# [388]	validation_0-auc:0.869758
# [389]	validation_0-auc:0.869839
# [390]	validation_0-auc:0.869861
# [391]	validation_0-auc:0.869932
# [392]	validation_0-auc:0.869978
# [393]	validation_0-auc:0.870051
# [394]	validation_0-auc:0.870057
# [395]	validation_0-auc:0.870164
# [396]	validation_0-auc:0.870237
# [397]	validation_0-auc:0.870292
# [398]	validation_0-auc:0.870414
# [399]	validation_0-auc:0.870442
# [400]	validation_0-auc:0.870507
# [401]	validation_0-auc:0.870559
# [402]	validation_0-auc:0.870601
# [403]	validation_0-auc:0.870683
# [404]	validation_0-auc:0.870693
# [405]	validation_0-auc:0.870724
# [406]	validation_0-auc:0.870751
# [407]	validation_0-auc:0.870818
# [408]	validation_0-auc:0.870909
# [409]	validation_0-auc:0.871002
# [410]	validation_0-auc:0.871046
# [411]	validation_0-auc:0.871088
# [412]	validation_0-auc:0.871166
# [413]	validation_0-auc:0.871275
# [414]	validation_0-auc:0.871301
# [415]	validation_0-auc:0.871306
# [416]	validation_0-auc:0.87135
# [417]	validation_0-auc:0.871364
# [418]	validation_0-auc:0.87138
# [419]	validation_0-auc:0.871403
# [420]	validation_0-auc:0.871444
# [421]	validation_0-auc:0.871473
# [422]	validation_0-auc:0.871528
# [423]	validation_0-auc:0.87155
# [424]	validation_0-auc:0.871671
# [425]	validation_0-auc:0.871697
# [426]	validation_0-auc:0.871751
# [427]	validation_0-auc:0.871823
# [428]	validation_0-auc:0.871855
# [429]	validation_0-auc:0.871868
# [430]	validation_0-auc:0.871897
# [431]	validation_0-auc:0.871951
# [432]	validation_0-auc:0.872056
# [433]	validation_0-auc:0.872069
# [434]	validation_0-auc:0.872091
# [435]	validation_0-auc:0.872098
# [436]	validation_0-auc:0.872101
# [437]	validation_0-auc:0.872225
# [438]	validation_0-auc:0.872282
# [439]	validation_0-auc:0.872325
# [440]	validation_0-auc:0.872334
# [441]	validation_0-auc:0.872414
# [442]	validation_0-auc:0.872492
# [443]	validation_0-auc:0.872571
# [444]	validation_0-auc:0.872637
# [445]	validation_0-auc:0.872728
# [446]	validation_0-auc:0.872748
# [447]	validation_0-auc:0.872765
# [448]	validation_0-auc:0.872777
# [449]	validation_0-auc:0.872814
# [450]	validation_0-auc:0.872875
# [451]	validation_0-auc:0.872942
# [452]	validation_0-auc:0.872988
# [453]	validation_0-auc:0.873015
# [454]	validation_0-auc:0.873105
# [455]	validation_0-auc:0.873182
# [456]	validation_0-auc:0.873239
# [457]	validation_0-auc:0.87328
# [458]	validation_0-auc:0.873381
# [459]	validation_0-auc:0.873417
# [460]	validation_0-auc:0.873456
# [461]	validation_0-auc:0.873506
# [462]	validation_0-auc:0.873522
# [463]	validation_0-auc:0.873549
# [464]	validation_0-auc:0.873554
# [465]	validation_0-auc:0.873602
# [466]	validation_0-auc:0.87366
# [467]	validation_0-auc:0.873732
# [468]	validation_0-auc:0.873751
# [469]	validation_0-auc:0.873808
# [470]	validation_0-auc:0.873857
# [471]	validation_0-auc:0.87396
# [472]	validation_0-auc:0.874026
# [473]	validation_0-auc:0.874101
# [474]	validation_0-auc:0.874134
# [475]	validation_0-auc:0.874174
# [476]	validation_0-auc:0.87424
# [477]	validation_0-auc:0.874258
# [478]	validation_0-auc:0.874273
# [479]	validation_0-auc:0.874281
# [480]	validation_0-auc:0.874345
# [481]	validation_0-auc:0.874394
# [482]	validation_0-auc:0.874416
# [483]	validation_0-auc:0.874494
# [484]	validation_0-auc:0.874558
# [485]	validation_0-auc:0.874572
# [486]	validation_0-auc:0.87458
# [487]	validation_0-auc:0.874597
# [488]	validation_0-auc:0.874725
# [489]	validation_0-auc:0.874823
# [490]	validation_0-auc:0.874855
# [491]	validation_0-auc:0.874969
# [492]	validation_0-auc:0.875023
# [493]	validation_0-auc:0.875001
# [494]	validation_0-auc:0.875028
# [495]	validation_0-auc:0.875143
# [496]	validation_0-auc:0.875265
# [497]	validation_0-auc:0.875313
# [498]	validation_0-auc:0.875341
# [499]	validation_0-auc:0.875356
# [500]	validation_0-auc:0.875408
# [501]	validation_0-auc:0.875452
# [502]	validation_0-auc:0.875577
# [503]	validation_0-auc:0.875649
# [504]	validation_0-auc:0.875677
# [505]	validation_0-auc:0.875709
# [506]	validation_0-auc:0.875732
# [507]	validation_0-auc:0.875871
# [508]	validation_0-auc:0.875915
# [509]	validation_0-auc:0.875927
# [510]	validation_0-auc:0.876005
# [511]	validation_0-auc:0.876029
# [512]	validation_0-auc:0.876082
# [513]	validation_0-auc:0.876094
# [514]	validation_0-auc:0.876115
# [515]	validation_0-auc:0.876145
# [516]	validation_0-auc:0.876227
# [517]	validation_0-auc:0.876263
# [518]	validation_0-auc:0.876355
# [519]	validation_0-auc:0.876383
# [520]	validation_0-auc:0.876421
# [521]	validation_0-auc:0.87644
# [522]	validation_0-auc:0.876554
# [523]	validation_0-auc:0.876666
# [524]	validation_0-auc:0.876689
# [525]	validation_0-auc:0.8768
# [526]	validation_0-auc:0.876893
# [527]	validation_0-auc:0.87695
# [528]	validation_0-auc:0.877017
# [529]	validation_0-auc:0.877037
# [530]	validation_0-auc:0.877063
# [531]	validation_0-auc:0.877068
# [532]	validation_0-auc:0.877052
# [533]	validation_0-auc:0.877059
# [534]	validation_0-auc:0.877097
# [535]	validation_0-auc:0.877111
# [536]	validation_0-auc:0.87714
# [537]	validation_0-auc:0.877164
# [538]	validation_0-auc:0.877228
# [539]	validation_0-auc:0.877283
# [540]	validation_0-auc:0.877308
# [541]	validation_0-auc:0.877336
# [542]	validation_0-auc:0.877352
# [543]	validation_0-auc:0.877432
# [544]	validation_0-auc:0.877508
# [545]	validation_0-auc:0.877577
# [546]	validation_0-auc:0.877633
# [547]	validation_0-auc:0.877702
# [548]	validation_0-auc:0.877753
# [549]	validation_0-auc:0.877851
# [550]	validation_0-auc:0.877876
# [551]	validation_0-auc:0.877945
# [552]	validation_0-auc:0.877918
# [553]	validation_0-auc:0.877947
# [554]	validation_0-auc:0.878011
# [555]	validation_0-auc:0.878017
# [556]	validation_0-auc:0.87807
# [557]	validation_0-auc:0.878102
# [558]	validation_0-auc:0.878223
# [559]	validation_0-auc:0.878331
# [560]	validation_0-auc:0.878388
# [561]	validation_0-auc:0.878397
# [562]	validation_0-auc:0.878425
# [563]	validation_0-auc:0.878461
# [564]	validation_0-auc:0.878478
# [565]	validation_0-auc:0.878527
# [566]	validation_0-auc:0.878548
# [567]	validation_0-auc:0.878622
# [568]	validation_0-auc:0.878693
# [569]	validation_0-auc:0.87878
# [570]	validation_0-auc:0.878836
# [571]	validation_0-auc:0.878993
# [572]	validation_0-auc:0.879071
# [573]	validation_0-auc:0.87908
# [574]	validation_0-auc:0.879097
# [575]	validation_0-auc:0.879166
# [576]	validation_0-auc:0.879213
# [577]	validation_0-auc:0.879303
# [578]	validation_0-auc:0.879312
# [579]	validation_0-auc:0.879407
# [580]	validation_0-auc:0.879436
# [581]	validation_0-auc:0.879455
# [582]	validation_0-auc:0.879482
# [583]	validation_0-auc:0.879506
# [584]	validation_0-auc:0.879517
# [585]	validation_0-auc:0.879566
# [586]	validation_0-auc:0.87964
# [587]	validation_0-auc:0.879668
# [588]	validation_0-auc:0.879787
# [589]	validation_0-auc:0.87986
# [590]	validation_0-auc:0.87987
# [591]	validation_0-auc:0.879899
# [592]	validation_0-auc:0.879964
# [593]	validation_0-auc:0.880012
# [594]	validation_0-auc:0.880055
# [595]	validation_0-auc:0.880061
# [596]	validation_0-auc:0.880094
# [597]	validation_0-auc:0.880104
# [598]	validation_0-auc:0.880255
# [599]	validation_0-auc:0.880275
# [600]	validation_0-auc:0.880314
# [601]	validation_0-auc:0.880361
# [602]	validation_0-auc:0.880368
# [603]	validation_0-auc:0.880467
# [604]	validation_0-auc:0.880555
# [605]	validation_0-auc:0.880584
# [606]	validation_0-auc:0.88062
# [607]	validation_0-auc:0.880753
# [608]	validation_0-auc:0.880771
# [609]	validation_0-auc:0.880805
# [610]	validation_0-auc:0.880837
# [611]	validation_0-auc:0.880838
# [612]	validation_0-auc:0.880845
# [613]	validation_0-auc:0.880889
# [614]	validation_0-auc:0.880958
# [615]	validation_0-auc:0.880951
# [616]	validation_0-auc:0.880992
# [617]	validation_0-auc:0.881071
# [618]	validation_0-auc:0.881075
# [619]	validation_0-auc:0.881155
# [620]	validation_0-auc:0.881181
# [621]	validation_0-auc:0.881223
# [622]	validation_0-auc:0.881256
# [623]	validation_0-auc:0.881277
# [624]	validation_0-auc:0.881299
# [625]	validation_0-auc:0.881381
# [626]	validation_0-auc:0.881416
# [627]	validation_0-auc:0.881486
# [628]	validation_0-auc:0.881521
# [629]	validation_0-auc:0.881608
# [630]	validation_0-auc:0.881674
# [631]	validation_0-auc:0.881755
# [632]	validation_0-auc:0.881808
# [633]	validation_0-auc:0.881853
# [634]	validation_0-auc:0.881859
# [635]	validation_0-auc:0.881992
# [636]	validation_0-auc:0.882083
# [637]	validation_0-auc:0.882094
# [638]	validation_0-auc:0.882165
# [639]	validation_0-auc:0.882185
# [640]	validation_0-auc:0.882282
# [641]	validation_0-auc:0.882339
# [642]	validation_0-auc:0.88235
# [643]	validation_0-auc:0.882352
# [644]	validation_0-auc:0.882415
# [645]	validation_0-auc:0.882493
# [646]	validation_0-auc:0.882574
# [647]	validation_0-auc:0.882607
# [648]	validation_0-auc:0.882635
# [649]	validation_0-auc:0.88269
# [650]	validation_0-auc:0.882728
# [651]	validation_0-auc:0.882745
# [652]	validation_0-auc:0.882815
# [653]	validation_0-auc:0.882859
# [654]	validation_0-auc:0.882987
# [655]	validation_0-auc:0.883015
# [656]	validation_0-auc:0.883027
# [657]	validation_0-auc:0.883058
# [658]	validation_0-auc:0.883087
# [659]	validation_0-auc:0.883146
# [660]	validation_0-auc:0.883206
# [661]	validation_0-auc:0.883298
# [662]	validation_0-auc:0.883329
# [663]	validation_0-auc:0.883389
# [664]	validation_0-auc:0.883426
# [665]	validation_0-auc:0.883475
# [666]	validation_0-auc:0.883523
# [667]	validation_0-auc:0.883559
# [668]	validation_0-auc:0.883617
# [669]	validation_0-auc:0.883644
# [670]	validation_0-auc:0.883671
# [671]	validation_0-auc:0.883706
# [672]	validation_0-auc:0.883714
# [673]	validation_0-auc:0.883807
# [674]	validation_0-auc:0.883814
# [675]	validation_0-auc:0.883835
# [676]	validation_0-auc:0.883913
# [677]	validation_0-auc:0.883942
# [678]	validation_0-auc:0.883983
# [679]	validation_0-auc:0.884064
# [680]	validation_0-auc:0.884153
# [681]	validation_0-auc:0.884235
# [682]	validation_0-auc:0.884238
# [683]	validation_0-auc:0.884329
# [684]	validation_0-auc:0.884347
# [685]	validation_0-auc:0.884449
# [686]	validation_0-auc:0.884465
# [687]	validation_0-auc:0.88451
# [688]	validation_0-auc:0.884691
# [689]	validation_0-auc:0.884732
# [690]	validation_0-auc:0.88476
# [691]	validation_0-auc:0.884843
# [692]	validation_0-auc:0.884883
# [693]	validation_0-auc:0.884955
# [694]	validation_0-auc:0.884974
# [695]	validation_0-auc:0.885105
# [696]	validation_0-auc:0.885123
# [697]	validation_0-auc:0.885184
# [698]	validation_0-auc:0.885192
# [699]	validation_0-auc:0.885287
# [700]	validation_0-auc:0.885351
# [701]	validation_0-auc:0.885374
# [702]	validation_0-auc:0.885418
# [703]	validation_0-auc:0.885436
# [704]	validation_0-auc:0.885492
# [705]	validation_0-auc:0.885508
# [706]	validation_0-auc:0.885524
# [707]	validation_0-auc:0.885582
# [708]	validation_0-auc:0.885624
# [709]	validation_0-auc:0.885673
# [710]	validation_0-auc:0.88572
# [711]	validation_0-auc:0.885738
# [712]	validation_0-auc:0.885785
# [713]	validation_0-auc:0.885801
# [714]	validation_0-auc:0.885816
# [715]	validation_0-auc:0.885844
# [716]	validation_0-auc:0.885936
# [717]	validation_0-auc:0.885985
# [718]	validation_0-auc:0.886001
# [719]	validation_0-auc:0.886031
# [720]	validation_0-auc:0.88606
# [721]	validation_0-auc:0.88607
# [722]	validation_0-auc:0.886123
# [723]	validation_0-auc:0.886138
# [724]	validation_0-auc:0.886176
# [725]	validation_0-auc:0.886198
# [726]	validation_0-auc:0.886273
# [727]	validation_0-auc:0.886298
# [728]	validation_0-auc:0.886392
# [729]	validation_0-auc:0.88645
# [730]	validation_0-auc:0.886536
# [731]	validation_0-auc:0.88659
# [732]	validation_0-auc:0.886608
# [733]	validation_0-auc:0.886608
# [734]	validation_0-auc:0.886621
# [735]	validation_0-auc:0.886689
# [736]	validation_0-auc:0.886728
# [737]	validation_0-auc:0.886761
# [738]	validation_0-auc:0.886779
# [739]	validation_0-auc:0.886834
# [740]	validation_0-auc:0.886884
# [741]	validation_0-auc:0.88692
# [742]	validation_0-auc:0.886937
# [743]	validation_0-auc:0.886971
# [744]	validation_0-auc:0.886999
# [745]	validation_0-auc:0.887027
# [746]	validation_0-auc:0.887118
# [747]	validation_0-auc:0.887139
# [748]	validation_0-auc:0.88721
# [749]	validation_0-auc:0.887242

# %%
y_pred = 0

for idx, clf in enumerate(clfEns):
    y_temp = clf.predict_proba(X_train)[:,1]
    print('clf {0} AUC:'.format(idx), roc_auc_score(y_train, y_temp))
    y_pred += y_temp

y_pred = y_pred/5.0
print('Overall AUC:', roc_auc_score(y_train, y_pred))
# Out:
# ('clf 0 AUC:', 0.88918026238010273)
# ('clf 1 AUC:', 0.88958667668867863)
# ('clf 2 AUC:', 0.88902126879334364)
# ('clf 3 AUC:', 0.88940578710440987)
# ('clf 4 AUC:', 0.89005475103934195)
# ('Overall AUC:', 0.88970673833031144)

# %%
# predicting
y_pred = 0
for clf in clfEns:
    y_pred+= clf.predict_proba(X_test)[:,1]
y_pred = y_pred/5.0

# %%
submission = pd.DataFrame(data=y_pred)
submission.to_csv("submission.csv", index=False, header=None)
